# %%
import pandas as pd

# %%
df = pd.read_csv('tensorflow-issues.csv', encoding = 'latin-1')

# %%
df
# Out:
#       number                                              title  \
# 0      16513                  TF1.5.0 not working with CUDA 8.0
# 1      16512     how to install ffmpeg in tensorflow 1.4 binary
# 2      16510  Feature Request: Make lstm2d.separable_lstm ac...
# 3      16509                                           Fix typo
# 4      16508       Check more cpu features for Clang on Windows
# 5      16507          ResourceExhaustedError, when running UNET
# 6      16506  Feature request: Have Estimator display Loss a...
# 7      16505                                         Remove BOM
# 8      16504  Issue propagating gradients through tf.while_loop
# 9      16503  Enable multi-dimensional and axis support for ...
# 10     16502  Java Android API: No OpKernel was registered t...
# 11     16501  Define Cr, Fr, Shared, Var to resolved undefin...
# 12     16500  contrib/learn: Typo in variable name x_exrta -...
# 13     16499  Extend tf.unique_with_counts to multi-dimensio...
# ...

# %%
import priority as pr

# %%
pr.runTool()
# Out:
# [1] Welcome to Issue Prioritizer
# Enter csv filename to read issuestensorflow-issues.csv
# [2] Reading issues from csv file...
# [3] Data frame created.
# [4] Converting data frame to issue list...
# [5] Issue list created.
# [6]
# Specify Priority order as:
# 1. author association
# 2. date created
# 3. assignees
# 4. comments
# Enter 4 space separated intergers: 2 4 3 1
# [7] Sorting issues as per the priority...
# [8] Converting back to Data Frame...
# [9] Returning sorted issues...
#         assignees author_association  comments            created_at  \
# number
# 18              0               NONE        76  2015-11-09T17:32:18Z
# 19              0               NONE        59  2015-11-09T17:33:09Z
# 22              1               NONE       494  2015-11-09T17:41:26Z
# 37              0               NONE       231  2015-11-09T20:17:58Z
# 70              0               NONE        21  2015-11-10T03:34:47Z
# ...
