# %%
import utilities as ut
import recRetrieve as rec
import pullRequests as pr
url = rec.default_url
params = ut.getParams()

# %%
rec.retrieve(url, params, pr.action)
# Out:
# Retrieving: https://api.github.com/repos/tensorflow/tensorflow/pulls?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16256?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [tflite] make calling NNAPI work again
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16253?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Introducing TensorRT operator
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16243?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16241?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix a buildscript error which prevents macro being used by other workspaces
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16237?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: support preconditioner for `conjugated_gradient()` in `linear_equations.py`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16232?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Singleton S3Client
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16220?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix result shape of tf.tensordot unknown when axes is an integer number
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16210?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: added CMake options to provide external zlib, GRPC, Eigen
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16206?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: make label_image for tflite build again
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16200?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Accepts `PathLike` objects for `model_dir`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16185?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add LU operation and return factorized matrices, related to #6992
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16176?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: 4d55397500 patch 1
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16175?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: remove ":arm" to build tflite on ARM64 linux
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16173?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add C++ toolchain for portable Linux builds
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16168?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix unicode string conversion issue in Python 2
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16158?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: GAN model: move generated and real operations under discriminator namespace
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16154?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added save_checkpoint_steps attribute to MonitoredTrainingSession
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16153?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: New features: tf.alphas and tf.alphas_like - Related to #16128
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16145?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Decoding contents of BMP file on big endian
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16142?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16134?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added training parameter to batch_normalization
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16133?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add training parameter to dropout to make it work
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16131?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update contrib/HVX readme
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16129?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: allow 'None' as batch size for TimeFreqLSTMCell
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16127?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix default parameters for TimeFreqLSTMCell, fixes #16100
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16123?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add `slide` method for Dataset
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16121?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enable some passes for graph_transform on Windows
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16120?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Utility classes for writing Java source code from a C++ process (part 3)
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16119?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Created ctc_loss_dense_labels in contrib.layers
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16118?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Minor improvements to TFRecord format docs
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16117?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add nsync lib dep. to cc_library rule android_tensorflow_lib_selective_registration
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16114?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update maxout.py
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16113?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Propagate the error string of GIF processing for decode_gif
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16105?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix crash in `tf.contrib.ffmpeg.decode_video`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16101?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add stream selection support for `tf.contrib.ffmpeg.decode_audio`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16088?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disable keras data_utils_test as it's flaky.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16085?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add unspecified dimensions (-1) support for noise_shape with tf.nn.dropout
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16084?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update download_dependencies.sh to prevent crash from 403
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16075?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: optimize_for_inference_lib.fold_batch_norms() preserves data_format
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16067?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [XLA] Separate out the dynamic slice wrapping tests
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16065?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: export tflite::Intepreter's  UseNNAPI() and setNumThreads() to java
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16064?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL DNN: fixed a bug related to feature column test in python
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16057?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make platform a proper module
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16051?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix crash on GPU (out of GPU memory) for `softmax_cross_entropy_with_logits`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16012?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix a bug in ResolveConstantConcat
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16006?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add property to get cell wrapped by DropoutWrapper
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16005?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Verbs w 0 copies
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16003?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Adding meta_graph_be.pb testdata for big endian for framework_meta_graph_test
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15989?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix freeze_graph command line argument error.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15982?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add broadcasting support for `tf.where`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15971?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix local path for hexagon_graph_execution in sample script
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15969?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix variable property of DropoutWrapper
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15967?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make graph transform tool accessible via command line for pip install.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15966?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: remove write_version=saver_pb2.SaverDef.V1
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15946?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Support for large number of classes when using tf.metrics.mean_per_class_accuracy()
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15940?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [tensorflow lite] add setUseNNAPI to the Interpreter class
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15934?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update docs and test cases for missing types in `tf.zeros_like`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15931?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Making SQLite better
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15926?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: _Assert3DImage that adds a control dependency for the shape check
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15906?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add additional argument to freeze_graph
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15896?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add EvalResultsExporter for writing the results of evaluation to a file
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15894?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Allow `~/` in path for transform_graph
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15893?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Transpose for high dimensional tensors using eigen
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15890?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Scope subprocess and tempfile imports in tensorflow lite to fix #15410
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15877?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Documentation fix to contrib.signals
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15861?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix LSTM Layer Normalization implementation to match original paper
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15858?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add unsortedsegment(prod/min/max/sqrt_n/mean).
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15855?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Export inception model after retrain
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15824?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Move SpeechActivity animation to XML.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15823?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix a pessimizing-move warning in GetDeviceLapackInfo()
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15822?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Updating error handling in normalize_tuple
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15809?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add checking for input values in GANHead constructor
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15801?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove calculation of unnecessary matrix columns in SVD gradient
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15786?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: order quantized table by value for ease of reading
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15778?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add `colors` support for `tf.image.draw_bounding_boxes`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15770?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix todo: make a class which constrcuts resource and provide get_next.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15762?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make unused variable warning an error during TF builds.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15743?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Including common.h with NEON_2_SSE.h
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15742?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Use Eigen version of the `scalar_pow_op` for `pow` ops
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15728?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Clarify the description of batch_norm in order to highlight the dimen…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15726?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Batch support for deterministic image ops
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15723?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Load region from `~/.aws/config` if possible in S3
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15678?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: De-Bazel pip_smoke_test sanity check
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15677?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: De-Bazel check_load_py_test sanity check
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15671?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Turn check_futures_test into a sanity check
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15670?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [CMake] Add sanity tests for python file lists
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15665?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled:  Fix NadamOptimizer to work with sparse gradients properly
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15640?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: adding ps_strategy to run_config to enable different placement strate…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15639?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix doc for benchmark_model for android
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15617?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix periodic resample
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15614?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Support Negativo17 Fedora Packaging
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15608?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: update _DECORATED_OPS for each latest call
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15607?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix `tf.pow(x, y)` edge case with integer x and negative integer y
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15606?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix issue #15588 by simplifying the code
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15595?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Issue #15572, support for unspecified spatial dimensions in layers.Conv3d_transposed
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15590?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled:  [CMake] Extract more file lists
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15586?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: WIP: Remove invalid merge_repeated option from CTC beam decoder
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15555?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: RGB<->YIQ colorspace conversion
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15535?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [iOS/tflite] Add ability to build a specific arch
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15531?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix sample_distorted_bounding_box where min_object_covered could be None
# Storing data in tensorflow.csv
# Limit Remaining: 4971
# Retrieving: https://api.github.com/repositories/45717250/pulls?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&page=2
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15500?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix pooling1D dimension bug
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15494?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enables 0-D indexing for Gather() in TFLite
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15489?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Hotfix/fix android example for focus mode continuous picture - #15487
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15469?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Compute test accuracy in batches to avoid OOM on GPUs
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15457?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Small fix in the example
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15455?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add customerized kernel implementation for clip_by_value
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15440?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make get_placeholders() accessible and add example
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15421?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add complex64 and complex128 support for `tf.angle` on GPU
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15408?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: New rolling window batch operation for tf.data.Dataset #15044
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15404?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: DOCS: Update the description of the fused parameter.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15402?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add complex64 and complex128 support for ApplyAdadelta kernel
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15399?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix bug: leaky relu supports float64
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15385?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Silence warning of graph_replace
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15382?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CMake: optionally link to ZLIB as systemlib / shared objects.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15381?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CMake: fix -fPIC control.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15379?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Only emit PTX code for the most recent CUDA compute architecture
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15366?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix that remove_nodes drops input suffixes
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15354?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CPU: Support for DT_STRING type in ScatterNd
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15337?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: added crucial documentation on SELU activation
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15309?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Correct channels_first format in 1d_pooling for tf.layers
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15307?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Setting proper sonames on Linux
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15299?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Model Average Optimizer
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15279?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Minor optimization of conv_ops.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15275?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [XLA] Allow components in the plugins directory to create devices
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15270?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix issue #15269
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15243?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add support for explicit broadcasting in TensorFlow
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15234?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix static shape inference for keras.layers.LSTM
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15201?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove extra param of concatenation in nnapi/NeuralNetworksShim.h
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15184?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add some sparse operators
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15183?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: estimator: allow export_outputs to be a Tensor
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15176?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix a problem in tflite custom_operators.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15168?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Adding reading op for hadoop sequence file format (very basic version though).
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15164?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: minor docs addition to fixed_size_partitioner
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15154?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add uint32 and uint64 kernel support for `Invert`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15130?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Synchronize threads for safe output
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15127?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: OS X ld does not have icf
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15109?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add a setter method variable_scope.auto_reuse_variables() to enable AUTO_REUSE
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15098?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: improve tf.saved_model.loader.load exception
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15092?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: min_quantize lib and command line
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15037?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Support "causal" padding in tf.layers.convolutional.Conv1D
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15017?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update freeze_graph.py
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14997?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add broadcasting for rank 6 Tensors
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14986?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: improvement in the tf.nn.raw_rnn documentation
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14983?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Switch over to max_pool_v2 in Python
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14974?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Support passing layer instances to produce attentional hidden states
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14953?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tensor roll op implementation
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14939?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add complex dtypes support for `tf.squared_difference`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14928?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Variable size multi-label candidate sampling.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14920?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix issue in tf.nn.softmax where negative dims could only be -1
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14908?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: TensorBoard Modifications for Word2Vec Example
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14895?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add `tf.unravel_index` as an equivalent of `np.unravel_index`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14872?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add DT_HALF support for SpaceToDepth on GPU
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14865?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix bug: divide by zero in embedding_lookup_sparse
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14853?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Automate download and unzip of the model file
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14847?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add label_wav_dir.py
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14843?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix crash on closing the app when classifier failed to initialize
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14842?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update .gitignore files for Android Studio
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14833?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix of issue #10479
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14727?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: New Feature: #12686 Softmaxcrossentropywithlogits gradient function
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14722?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add a way to provide target nodes in Android
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14690?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added a check for a macro to specify that an ARM device is not mobile
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14604?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Implement LoggingAsync for GRPC Worker Services
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14598?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: upgrade minSdkVersion to 21
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14592?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add photo selection and some changes in ios simple app
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14578?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Implements LayerNormBasicGRUCell
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14569?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Converting the real and imaginary float values from short_test_segmen…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14557?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Improve SkipNBytes to RandomInputStream
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14552?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make sparse_to_dense differentiable by wrapping scatter_nd_add.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14351?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: memmap changes
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14341?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add checkpoint file prefix check
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14319?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add not equal op to tf_op_files.txt
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14318?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: updated keras backend with missing methods
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14251?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add int64 support of `axis` (`Tidx`) for ConcatV2
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14237?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added an option to `kernel` to `skip_metropolis_step`.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14183?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: improve production condition of debug log with VLOG
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14098?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add KafkaReader for processing streaming data with Apache Kafka
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13991?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Support fold batch norm for atrous conv2d
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13985?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update adding_an_op.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13954?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: make "smart_cond" api public and reusable
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13817?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: allow to run configure from a parent workspace
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13557?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix the gradient computation of dynamic stitch.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13382?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix of issue #13164
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13330?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Extracting out tf.bin_values_fixed_width from tf.histogram_fixed_width.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13326?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: added scope filtering to summaries.merge_all
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13312?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Support TensorArray in BeamSearchDecoder state.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13259?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Implement SpatialPyramidPooling
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/13027?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: persist nsync.a across different platform builds
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12971?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add utf8 support for string_split
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12936?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: change cnn_mnist example to use Adam optimizer; added a 'loss' summary
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12658?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Support CopyFile with streaming
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12637?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Adding image captioning examples for iOS (Im2txt)
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12549?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: layers.py spatial_softmax activation can be selected by user
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12487?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make scatter_* kernels to be multiple thread and gain 8x speedup.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12408?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [XLA][WIP] Add support for Polyhedral compilation through Polly
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12316?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: training argument for tf.nn.rnn_cell.DropoutWrapper
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12257?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add focal_loss
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/12175?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [OpenCL] Registers AvgPool and AvgPoolGrad (#105)
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/11573?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Weight normalization for RNN Cells.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/11545?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add nodouble option for all cwise ops
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/10752?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: BeamSearchDecoder: fix beam not full, and add test module
# Storing data in tensorflow.csv
# Limit Remaining: 4870
# Retrieving: https://api.github.com/repositories/45717250/pulls?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&page=3
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/9933?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Multiplicative Integration Recurrent Neural Networks
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/9924?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Quantize conv2d transpose
# Storing data in tensorflow.csv
# Limit Remaining: 4769

# %%
ls
# Out:
#  Volume in drive F is New Volume
#  Volume Serial Number is CC9D-6DEA
#
#  Directory of F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts
#
# 01/20/2018  12:09 PM    <DIR>          .
# 01/20/2018  12:09 PM    <DIR>          ..
# 01/20/2018  11:59 AM    <DIR>          .ipynb_checkpoints
# 01/20/2018  11:57 AM    <DIR>          __pycache__
# 01/20/2018  10:21 AM             1,335 oldPullRequests.py
# 01/20/2018  11:57 AM             1,156 pullRequests.py
# 01/20/2018  10:36 AM             1,274 recRetrieve.py
# 01/20/2018  11:04 AM            11,688 running-scripts.ipynb
# 01/20/2018  12:09 PM            14,690 tensorflow.csv
# 01/20/2018  01:00 AM            16,204 Untitled.ipynb
# 01/20/2018  12:09 PM            53,845 Untitled1.ipynb
# 01/20/2018  12:15 AM               348 utilities.py
#                8 File(s)        100,540 bytes
#                4 Dir(s)  230,993,510,400 bytes free

# %%
import pandas as pd

# %%
df = pd.read_csv('tensorflow.csv', encoding = 'latin-1')

# %%
df
# Out:
#                                                  title  commits  additions  \
# 0               [tflite] make calling NNAPI work again        1          0
# 1                        Introducing TensorRT operator        1       4589
# 2                                             fix typo        1          2
# 3    Fix a buildscript error which prevents macro b...        1          5
# 4    support preconditioner for `conjugated_gradien...        3         84
# 5                                   Singleton S3Client        2         75
# 6    Fix result shape of tf.tensordot unknown when ...        1          2
# 7    added CMake options to provide external zlib, ...        1        533
# 8              make label_image for tflite build again        2         47
# 9           Accepts `PathLike` objects for `model_dir`        3         28
# 10   add LU operation and return factorized matrice...       15        276
# 11                                  4d55397500 patch 1        3          4
# 12        remove ":arm" to build tflite on ARM64 linux        1          0
# 13         Add C++ toolchain for portable Linux builds        1        883
# 14     Fix unicode string conversion issue in Python 2        3         37
# 15   GAN model: move generated and real operations ...        1          9
# 16   Added save_checkpoint_steps attribute to Monit...        1         41
# 17   New features: tf.alphas and tf.alphas_like - R...        2         92
# 18         Decoding contents of BMP file on big endian        1         15
# 19                                            fix typo        1          1
# 20     Added training parameter to batch_normalization        1          4
# 21   Add training parameter to dropout to make it work        1          1
# 22                           Update contrib/HVX readme        1         84
# 23     allow 'None' as batch size for TimeFreqLSTMCell        2          1
# 24   fix default parameters for TimeFreqLSTMCell, f...        1          1
# 25                      add `slide` method for Dataset        3        620
# 26   Enable some passes for graph_transform on Windows        2          5
# 27   Utility classes for writing Java source code f...        2        952
# 28     Created ctc_loss_dense_labels in contrib.layers        5         48
# 29          Minor improvements to TFRecord format docs        1          5
# ..                                                 ...      ...        ...
# 172  Add int64 support of `axis` (`Tidx`) for ConcatV2        3         72
# 173  Added an option to `kernel` to `skip_metropoli...        2         85
# 174  improve production condition of debug log with...        1         15
# 175  Add KafkaReader for processing streaming data ...       18        928
# 176          Support fold batch norm for atrous conv2d        1        162
# 177                             Update adding_an_op.md        1        349
# 178          make "smart_cond" api public and reusable       14        124
# 179     allow to run configure from a parent workspace        1         71
# 180    Fix the gradient computation of dynamic stitch.        9        868
# 181                                Fix of issue #13164       30     137544
# 182  Extracting out tf.bin_values_fixed_width from ...       10        122
# 183       added scope filtering to summaries.merge_all        4          4
# 184    Support TensorArray in BeamSearchDecoder state.       14        244
# 185                    Implement SpatialPyramidPooling       25        217
# 186   persist nsync.a across different platform builds        4          8
# 187                  Add utf8 support for string_split       15        465
# 188  change cnn_mnist example to use Adam optimizer...        1          2
# 189                    Support CopyFile with streaming       10        133
# 190  Adding image captioning examples for iOS (Im2t...        2       2675
# 191  layers.py spatial_softmax activation can be se...        4         35
# 192  Make scatter_* kernels to be multiple thread a...        7         64
# 193  [XLA][WIP] Add support for Polyhedral compilat...        4        667
# 194  training argument for tf.nn.rnn_cell.DropoutWr...        4         44
# 195                                     Add focal_loss        5        168
# 196  [OpenCL] Registers AvgPool and AvgPoolGrad (#105)        1        374
# 197                Weight normalization for RNN Cells.        3        350
# 198              add nodouble option for all cwise ops        2        141
# 199  BeamSearchDecoder: fix beam not full, and add ...       11        101
# 200  Multiplicative Integration Recurrent Neural Ne...        6        414
# 201                          Quantize conv2d transpose       23        686
#
#      deletions  changed_files author_association
# 0            1              1        CONTRIBUTOR
# 1           16             35               NONE
# 2            2              2        CONTRIBUTOR
# 3            5              1               NONE
# 4           10              4               NONE
# 5           76              3               NONE
# 6            1              1        CONTRIBUTOR
# 7          339             15        CONTRIBUTOR
# 8           30              3        CONTRIBUTOR
# 9            5              4               NONE
# 10           1              9               NONE
# 11           1              1        CONTRIBUTOR
# 12           5              1        CONTRIBUTOR
# 13           0              6             MEMBER
# 14           4              2             MEMBER
# 15           7              1               NONE
# 16           6              2               NONE
# 17           0              2        CONTRIBUTOR
# 18           0              1        CONTRIBUTOR
# 19           1              1               NONE
# 20           4              1               NONE
# 21           1              1               NONE
# 22          61              3        CONTRIBUTOR
# 23           1              1               NONE
# 24           1              1               NONE
# 25           0              9        CONTRIBUTOR
# 26           9              2               NONE
# 27           0              7        CONTRIBUTOR
# 28           3              2               NONE
# 29           5              1        CONTRIBUTOR
# ..         ...            ...                ...
# 172         45              2             MEMBER
# 173          1              2               NONE
# 174          6              2               NONE
# 175          1             13             MEMBER
# 176          0              2               NONE
# 177          0              1               NONE
# 178         49              5               NONE
# 179         16              4        CONTRIBUTOR
# 180         10             11        CONTRIBUTOR
# 181      57501           1838        CONTRIBUTOR
# 182          0              3               NONE
# 183          3              2               NONE
# 184         15              4        CONTRIBUTOR
# 185          0              2        CONTRIBUTOR
# 186          1              1        CONTRIBUTOR
# 187         13              8             MEMBER
# 188          1              1        CONTRIBUTOR
# 189         12              7             MEMBER
# 190         12             30               NONE
# 191          3              2               NONE
# 192         57              2        CONTRIBUTOR
# 193          3              8               NONE
# 194         11              2        CONTRIBUTOR
# 195          0              3        CONTRIBUTOR
# 196          0              1        CONTRIBUTOR
# 197          0              2               NONE
# 198         49             40        CONTRIBUTOR
# 199         16              2               NONE
# 200          0              3               NONE
# 201         15              7        CONTRIBUTOR
#
# [202 rows x 6 columns]
