# %%
import recRetrieve as rec
import utilities as ut
import issues as iss

# %%
url = 'https://api.github.com/repos/tensorflow/tensorflow/issues'
params = ut.getParams()
params['state'] = 'open'

# %%
rec.retrieve(url, params, iss.action)
# Out:
# Retrieving: https://api.github.com/repos/tensorflow/tensorflow/issues?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=open
# [1] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16513?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: TF1.5.0 not working with CUDA 8.0
# [2] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16512?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: how to install ffmpeg in tensorflow 1.4 binary
# [3] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16510?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature Request: Make lstm2d.separable_lstm accept Dynamic Batch Sizes
# [4] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16509?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo
# [5] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16508?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Check more cpu features for Clang on Windows
# [6] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16507?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: ResourceExhaustedError, when running UNET
# [7] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16506?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature request: Have Estimator display Loss and Metrics for Every Epoch and not Every Step
# [8] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16505?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove BOM
# [9] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16504?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Issue propagating gradients through tf.while_loop
# [10] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16503?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enable multi-dimensional and axis support for tf.unique_with_counts
# [11] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16502?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Java Android API: No OpKernel was registered to support Op 'ListDiff'
# [12] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16501?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Define Cr, Fr, Shared, Var to resolved undefined names
# [13] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16500?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: contrib/learn: Typo in variable name x_exrta --> x_extra
# [14] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16499?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Extend tf.unique_with_counts to multi-dimensional tensors
# [15] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16498?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Bounding box do not remove
# [16] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16497?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: SpatialConvolution in tflite is very slow
# [17] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16496?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature Suggestion: "Float-bit-strings"
# [18] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16494?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enable [no]unroll for Clang on Windows
# [19] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16493?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Keras "Output missing from loss dictionary"
# [20] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16492?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Clang on Windows will define __BYTE_ORDER__ etc. for us
# [21] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16491?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove all_opensource_files
# [22] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16490?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tflite windows
# [23] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16489?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix document typo
# [24] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16488?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Travis trusty Ubuntu 14.04.5: module compiled against API version 0xc but this version of numpy is 0xb
# [25] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16486?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Change RELEASE.md to specify CUDA 9.0
# [26] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16485?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: resolve undefined name array_ops
# [27] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16484?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: use gather_nd to _gather_states in LSTMBlockWapper & fix SRU call return type
# [28] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16483?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Test case for session_partial_run_test.py is getting failed
# [29] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16482?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Specify CUDA 9.0 version
# [30] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16481?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Container localhost does not exist.
# [31] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16480?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CMake fixes, able generate reusable shared lib for C++ interface by find_package
# [32] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16477?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Windows Installation tutorial has wrong cuda version requirement, 9.0 required for latest version.
# [33] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16476?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tflite SSD Postprocessing
# [34] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16473?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixing hard_sigmoid's documentation to match impl
# [35] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16468?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Keras multi input and estimator
# [36] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16466?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Feature request] Adding a PR curves to canned estimators for (binary) classifiers
# [37] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16465?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: bug with frame_step in tf.contrib.signal.frame or overlap_and_add (or am I doing something wrong?)
# [38] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16464?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: AssignAddVariableOp has no output
# [39] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16461?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: macOS mnist download error
# [40] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16460?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix missing .
# [41] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16456?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: 'InputFnOps' object has no attribute 'receiver_tensors'
# [42] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16455?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Set training=True in BatchNormalization layer causes evaluation error in custom Estimator model
# [43] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16453?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Updated roadmap?
# [44] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16452?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Semantic Segmentation API
# [45] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16446?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: use tflite bilinear op to resize input of label_image
# [46] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16443?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disable AWS S3 virtual addressing
# [47] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16442?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: why save model and deploy in android device, the outputs are not the same as in ubuntu?
# [48] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16440?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: raw_input() was removed in Python 3
# [49] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16433?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix an imperfect implementation of tf.losses.mean_pairwise_squared_error
# [50] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16431?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Lite: Supporting Raspberry Pi.
# [51] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16428?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: want keras to work on GPU, but actually on CPU
# [52] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16424?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Dependency on old version of bleach (1.5)
# [53] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16418?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: common global variable with constant.py
# [54] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16404?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: remove SRU num_units == x.shape[-1] restriction
# [55] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16397?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: S3 accessing reports "Curl returned error code 6" after AWS SDK upgrading to 1.3.15
# [56] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16396?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.image.resize_image_with_crop_or_pad() is taking too much time to process an image or batch of images
# [57] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16395?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: change from deprecated version to a new version
# [58] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16393?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tensorflow object detection issue
# [59] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16391?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added early stopping and CheckpointSaverListeners to train and evaluate
# [60] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16390?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Maybe bug in quantize_graph.py
# [61] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16388?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: java.lang.InternalError: Cannot find requested resource bundle for locale en_US
# [62] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16387?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tensorflow not using GPU
# [63] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16385?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Estimator built with keras.estimator.model_to_estimator fails on Estimator.export_savedmodel
# [64] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16381?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Distributed TensorFlow without shared directory
# [65] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16374?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: No module named 'tensorflow.contrib.lite.toco.python'
# [66] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16370?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add hooks for mutate variables in tf.Estimator
# [67] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16368?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix of issue #13164 (Merges #13382)
# [68] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16365?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Include grpc_tensorflow_std_server in Docker image
# [69] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16364?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Standardizing the saved format and/or converting to big-endian on read
# [70] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16363?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Warning: Table trying to initialize from file ... is already initialized
# [71] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16357?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Increase tolerance in `losses_impl_test.py`. fixes #16238
# [72] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16356?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: How leave only 1 app and how edit drawing boxes?
# [73] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16352?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: OrderedEnqueuer not imported in keras/utils/__init__.py
# [74] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16350?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: There is an issue with your "new issue" page
# [75] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16348?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Change RELEASE.md to specify CUDA version
# [76] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16345?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.nn.sparse_softmax_cross_entropy_with_logits get error:  ValueError: Rank mismatch: Rank of labels (received 1) should equal rank of logits minus 1 (received 4).
# [77] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16344?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Variance of weights initialized with tf.variance_scaling_initializer is somewhat surprising
# [78] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16343?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.data.Dataset doesn't provide a good workflow for generating custom samples from large files
# [79] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16342?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixed documentation formatting
# [80] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16338?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Obtain tower id when using tf.contrib.estimator.replicate_model_fn()
# [81] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16334?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: save_steps in MoniteredTrainingSession
# [82] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16333?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Computing gradients of loop variables return None
# [83] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16329?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.nn.seq2seq.embedding_rnn_seq2seq
# [84] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16327?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: iOS app does not output predictions using resnet50
# [85] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16323?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Does Broadcast in TF copy first or just do ops along the axis
# [86] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16322?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: py_func convert unicode string results to bytes for python2
# [87] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16319?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add alternative paths for CUDA installation.
# [88] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16317?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tensorflow crash on android mobile with libtensorflowlite_jni.so of arm-v7a
# [89] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16312?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Allow step callback for scipy SLSQP
# [90] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16311?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Segmentation fault in _pywrap_tensorflow_internal.so
# [91] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16308?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: A crash found on tensorflow_jni.so when create interpreter using byteBufferMode
# [92] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16306?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add LINM (Loop Invariant Node Motion) optimization pass in GraphOptim…
# [93] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16302?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update README.md
# [94] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16301?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update README.md
# [95] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16300?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add tf.multi_one_hot that one-hot encodes multiple columns of Tensor
# [96] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16291?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [bug] Specify GPU device error when using session_options.config.mutable_gpu_options()->set_visible_device_list
# [97] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16287?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Bug] LuongMonotonicAttention in contrib/seq2seq/python/ops/attention_wrapper.py
# [98] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16285?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf-seq2seq, nmt, tensorflow's seq2seq diff
# [99] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16284?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [bug?] Tensorflow accepts CUDA_VISIBLE_DEVICES but still allocates memory on multiple GPUs
# [100] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16282?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Adding go_package to proto definition files necessary for Tensorflow serving
# Storing data in tensorflow-issues.csv
# Caught an exception. Contnuing now....
# Caught an exception. Contnuing now....
# Caught an exception. Contnuing now....
# Caught an exception. Contnuing now....
# Limit Remaining: 4698
# Retrieving: https://api.github.com/repositories/45717250/issues?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=open&page=2
# [1] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16279?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: While using tf.while_loop , the _Slicehelper chooses strided_slice op(req 4 args) instead of slice op(req 3 args)
# [2] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16276?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Linking against system-installed cuda and cudnn
# [3] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16266?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: No OpKernel was registered to support Op 'RandomShuffleQueueV2' with these attrs.
# [4] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16263?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: losses.softmax_cross_entropy documentation on tensor rank
# [5] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16261?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tensorflow Debug tfdbg ValueError with combined loss functions.
# [6] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16260?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: easier installation debugging
# [7] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16259?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix two small issues of XLA
# [8] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16258?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled:  Enhance layout optimization logic to remove duplicated layout transp…
# [9] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16257?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: feature request: KL distance for Gaussian Mixture Model
# [10] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16253?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Introducing TensorRT operator
# [11] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16248?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [bug?] Error in `python': malloc(): memory corruption
# [12] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16247?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [doc][feature request] Graphical representation of operations
# [13] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16246?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Failed to build error: mismatched argument pack lenghts...
# [14] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16239?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Not supported for GpuManagedAllocator
# [15] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16234?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: The recognized result is not correct when converting the frozen graph to tflite for android device use
# [16] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16231?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: x86_64 compilation failed
# [17] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16228?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.contrib.rnn.LSTMCell()  dtype not defined. Error when creating initializer for bias variable.
# [18] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16227?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.contrib.factorization.KMeansClustering cannot save model
# [19] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16226?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Include netstat in the tensorflow docker container
# [20] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16225?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: maxout lose the number of features in the shape of its output
# [21] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16219?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: build&link tensorflow lite c++ library Error
# [22] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16218?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [feature request ? ]  How to return SparseTensor when custom ops
# [23] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16216?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Resize tensor in tflite
# [24] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16214?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Unable to locate package cuda-command-line-tools
# [25] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16213?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Non-chief replicas freeze after chief completes training
# [26] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16210?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: added CMake options to provide external zlib, GRPC, Eigen
# [27] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16209?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: process blocked in session.run
# [28] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16207?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Socket issue of run whl
# [29] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16205?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Graph Transform Tool unable to build in TF source r1.5?
# [30] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16203?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature Request: Add CheckpointSaverListener to tf.contrib.learn.Experiment
# [31] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16202?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: regarding the deconvolution operation for conv1d
# [32] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16197?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add broadcasting to `softmax_cross_entropy_with_logits`
# [33] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16194?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Cannot interpret feed_dict key as Tensor: The name 'DecodeJpeg/contents:0' refers to a Tensor which does not exist. The operation, 'DecodeJpeg/contents', does not exist in the graph.
# [34] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16190?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: ValueError: Inputs to `Dense` should have rank >= 2.
# [35] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16189?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Will tf-Lite have GPU support , if the answer is yes ,the compute API will be which one ,OpenCL or gles ?
# [36] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16187?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Faster R-CNN: too many resources requested for launch
# [37] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16186?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: A bug when applying MultiRNNCell?
# [38] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16185?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add LU operation and return factorized matrices, related to #6992
# [39] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16184?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tensorflow and libcuda.so.1
# [40] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16182?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: What are the relation ship between TF.Slim, TF high level API and Keras
# [41] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16181?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: How to control the number of threads on Tensorflow and TF-Slim?
# [42] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16180?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tensorboard is down after upgrading the tensorflow?
# [43] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16179?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: ProfilerHook and loading libcupti.so cause Ubuntu to completely freeze
# [44] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16175?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: remove ":arm" to build tflite on ARM64 linux
# [45] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16174?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Failed to Create Session: CUDA_ERROR_UNKNOWN
# [46] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16170?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.train.latest_checkpoint fails when paths have "//"
# [47] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16167?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Documentation Method Templates Improvement
# [48] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16166?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: import error cudnnSetRNNDescriptor_v6 in tensorflow
# [49] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16164?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Accidentally cancelled inceptionV3 during install, now can't install at all
# [50] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16163?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Dataset.from_generator doesn't release memory after recreating the session
# [51] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16162?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: segmentation fault when calling help on GraphNodeProto
# [52] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16155?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Bug] slim.tfexample_decoder.TFExampleDecoder() crashes if RAW image with float type is used.
# [53] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16154?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added save_checkpoint_steps attribute to MonitoredTrainingSession
# [54] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16152?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: DeprecationWarning from `inspect.getargspec()`
# [55] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16150?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tensorflow Debugger with Multithreading
# [56] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16147?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Inference on V100 with TF1.5 is extremely slow.
# [57] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16146?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Documentation for GridLSTMCell is lacking and does not match the paper
# [58] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16143?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Undefined symbol "_ZN3Aws8Security14SecureMemClearEPhj"
# [59] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16139?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Segmentation fault when running optimization step with 3d convolution
# [60] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16138?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Build fails with Visual Studio 2017
# [61] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16136?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Error while using cuda-9.1, libcublas.so.8.0: cannot open shared object file: No such file or directory
# [62] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16134?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added training parameter to batch_normalization
# [63] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16133?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add training parameter to dropout to make it work
# [64] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16129?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: allow 'None' as batch size for TimeFreqLSTMCell
# [65] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16128?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Improvement Proposal - tf.alphas_like (merging tf.ones_like and tf.zeros_like into one)
# [66] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16126?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Error 	LNK1181	cannot open input file 'To.obj' ConsoleApplication1
# [67] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16123?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add rolling window batch operation for tf.data.Dataset
# [68] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16121?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enable some passes for graph_transform on Windows
# [69] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16120?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Utility classes for writing Java source code from a C++ process (part 3)
# [70] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16117?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add nsync lib dep. to cc_library rule android_tensorflow_lib_selective_registration
# [71] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16116?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Implement Scale Operate??
# [72] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16115?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Gradients w.r.t. eigenvalues/eigenvectors
# [73] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16114?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update maxout.py
# [74] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16112?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Define gradient for tf.linspace and make it work with higher-rank tensors, not just scalars.
# [75] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16110?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Using tf1.4 to restore a model from tf0.8, a NotFoundError appeared
# [76] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16108?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: No tf.metrics.true_negatives
# [77] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16104?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature request: Allow the build to use the system-installed protobuf lib
# [78] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16102?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Bug]: Unable to update the batch_normalization layer moving_mean/moving_variance of keras
# [79] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16098?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Question about r1.5's default ptxas GPU back-end
# [80] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16097?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: terminate called after throwing an instance of 'std::bad_alloc'
# [81] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16095?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Implement Scale Operate??
# [82] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16091?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Failed to convert tf gb file to tflite format
# [83] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16087?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled:   tf.estimator.train_and_evaluate list  of eval_spec
# [84] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16085?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add unspecified dimensions (-1) support for noise_shape with tf.nn.dropout
# [85] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16083?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Tensorflow and Bazle build in Docker Container on Windows
# [86] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16082?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Connect Apache Beam/Spark to TensorFlow (MonitoredTrainingSession) in a streaming manner?
# [87] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16076?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Using self.test_session() in setUp() in tf.test.TestCase runs setUp but not tearDown
# [88] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16075?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: optimize_for_inference_lib.fold_batch_norms() preserves data_format
# [89] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16072?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Dynamic Bi-directional RNN vs Dynamic RNN.- Not working as expected.
# [90] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16065?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: export tflite::Intepreter's  UseNNAPI() and setNumThreads() to java
# [91] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/16063?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: `tools/ci_builds/pi/build_raspberry_pi.sh`: '__PTHREAD_SPINS' was not declared in this scope
# ...
# Working on pull request titled: bazel build should warn you if you haven't run ./configure
# [85] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/4337?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Multi-CPU kernel for sparse_tensor_dense_matmul
# [86] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/4290?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Aspect Preserving Image Downsample That does not Require Cropping
# [87] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/4227?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: SparseTensor doesn't have get_shape() function
# [88] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/4193?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CTC loss is numerically unstable for long sequence lengths
# [89] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/4090?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make CUDA library version numbers available from python
# [90] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/4003?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Print Version of cuDNN Being Used
# [91] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3945?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature request: extend tf.select to broadcast a scalar condition
# [92] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3862?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.cumprod's gradient produces nans given zeros
# [93] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3851?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CSV decode error
# [94] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3840?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: missing return statement at end of non-void function
# [95] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3638?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.gather produces zeros for invalid indices on GPU
# [96] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3636?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Inception retraining / transfer learning can only utilize one CPU core and one GPU
# [97] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3628?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Unable to import frozen graph with batchnorm
# [98] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3519?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Suggestions for simplifying directory structure
# [99] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3502?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Streaming_mean along specific dimension
# [100] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3392?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove unnecessary input-size requirement for convolutions with padding='SAME'
# Storing data in tensorflow-issues.csv
# Caught an exception. Contnuing now....
# Limit Remaining: 4132
# Retrieving: https://api.github.com/repositories/45717250/issues?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=open&page=15
# [1] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3350?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: No GPU implementation of determinant and no gradient of determinant?
# [2] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3334?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.case doesn't preserve shape information
# [3] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3332?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature Request: Support for depthwise convolution by groups
# [4] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/3001?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Use Basic neural network subroutines (BNNS) on iOS
# [5] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2916?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Feature] RDMA support for distribued Tensorflow
# [6] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2807?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Slow quantized graph
# [7] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2793?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Clipping gradient w.r.t. inputs at each time step for RNN/LSTM
# [8] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2789?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: DropoutWrapper has unintended mask behavior when random seed is set
# [9] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2625?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Numerically stable summation methods
# [10] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2594?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add tf.assert for GPU (maybe also host-memory Const[string] for GPU) was: dynamic_rnn GPU support error
# [11] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2412?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Packaged TensorFlow C++ library for bazel-independent use
# [12] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2305?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: FR: Create/Support an automated hyperparameter selector like TPOT
# [13] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2291?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add -lm (Was: undefined reference to symbol 'ceil@@GLIBC_2.2.5)
# [14] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2217?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Wrap cuSOLVER in stream
# [15] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2169?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Unpooling layer in tensorflow
# [16] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2146?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CTC GPU support
# [17] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2126?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Auto device placement for distributed runtime
# [18] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/2118?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Default for tf.nn.conv2d_transpose output_shape
# [19] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1882?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Distortions in Retrain.py (Transfer learning w/ inception model) take exceedingly long
# [20] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1843?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Implement an efficient AssignMatMul() for general BLAS GEMM pattern
# [21] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1763?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: image processing functions should not convert dtypes unless necessary (e.g. resize/crop/transpose/rotate, ...)
# [22] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1736?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Batch normalization for RNNs
# [23] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1686?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Distributed cluster manager support: Slurm
# [24] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1604?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature request: Implementing spatially-sparse conv networks in TensorFlow
# [25] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1592?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Binary ops
# [26] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1539?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [clang+CUDA] No ZeroesLike[DT_BOOL] kernel
# [27] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1374?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Document trick with slash in scope names
# [28] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1325?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: tf.get_variable() cannot recognize existing variables
# [29] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/1122?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Easy to use batch norm layer.
# [30] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/971?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Expose TensorFlow build details
# [31] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/956?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Feature request: other types of padding besides zero-padding.
# [32] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/823?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Give a convenient way to retrieve shadow variables created by ExponentialMovingAverage.
# [33] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/781?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: rotate an image for data augmentation
# [34] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/720?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make tensorflow and tensorflow-devel deb packages
# [35] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/675?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Gradients of non-scalars (higher rank Jacobians)
# [36] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/636?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Implementation for GPU depthwise max pooling
# [37] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/631?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Provide sugar for insuring gradient computation of an op is put on the desired device
# [38] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/464?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: RMSProp optimization support for sparse tensors
# [39] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/436?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Need better error message for error in checkpoint loading
# [40] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/378?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: matmul gradients incorrect with complex64 tensors
# [41] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/360?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Warn when calling session.run() on a very large scatter
# [42] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/252?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make TensorFlow compatible with PyPy
# [43] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/216?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MatMul Broadcasting / tensordot
# [44] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/152?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Segmentation fault when GPUs are already used
# [45] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/70?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Human Consumable Language Independent DSL
# [46] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/37?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Node.js (JavaScript) Wrapper API
# [47] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/22?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: OpenCL support
# [48] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/19?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Swift API
# [49] url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/issues/18?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: C# api
# Storing data in tensorflow-issues.csv
# Limit Remaining: 4031

# %%
import pandas as pd

# %%
df = pd.read_csv('tensorflow-issues-closed.csv', encoding = 'latin-1')

# %%
df
# Out:
#      number                                              title  \
# 0     16731                            Fixed a couple of typos
# 1     16716  Linker Tools Error encountered when use StepStats
# 2     16707          Can't initialize an all zero SparseTensor
# 3     16695            Padding algo is not working as doc says
# 4     16690                              change to anchor link
# 5     16688            how to assign the GPU device using C++?
# 6     16684  The link for the  tutorial on Google's Tensorf...
# 7     16680                                   Branch 184220615
# 8     16674                                   Fix sanity build
# 9     16672                 Updating the version to 1.6.0-rc0.
# 10    16662  Current Bazel version is 0.10.0, expected at l...
# 11    16661                       Fix "Define the model" link.
# 12    16658              Runtime Error with Qt GUI Application
# 13    16657                        Tensorflow on banana-pi m64
# 14    16654   Bazel version comparison fails with bazel 0.10.0
# 15    16653                                           Fix docs
# 16    16652                              v1.3 batch_norm layer
# 17    16651    Temporarily remove three linter checks for now.
# 18    16646  can tf.estimator.Estimator's  parameters be mo...
# 19    16645  What's the difference between Univariate predi...
# 20    16636  Add relnote about bug in ptxas in CUDA 9 and 9.1.
# 21    16631           Allow variable_overwrites on scope level
# 22    16628  Tensorflow switches to CPU when using Variable...
# 23    16626  example script multivariate.py throws "UserWar...
# 24    16625  [For Test; DO NOT MERGE] Add grpcio as a pip d...
# 25    16621  Using tf.train.SyncReplicasOptimizer with mult...
# 26    16620  How to use model.summary() when using placehol...
# 27    16612  Simplify loader_impl.py logic around main Op T...
# 28    16607                    MKL: Pooling and AddN bug fixes
# 29    16605  Description in docs of one-hot vector for mnis...
# ..      ...                                                ...
# 252   16007   Fix inline if/else statement in CMAKE_CACHE_ARGS
# 253   16006  Add property to get cell wrapped by DropoutWra...
# 254   16005                                   Verbs w 0 copies
# 255   16003  Adding meta_graph_be.pb testdata for big endia...
# 256   16002                               fix a_ to allocator_
# 257   15998         tensorflow input/output tensor reshape c++
# 258   15995  /home/hp/.cache/bazel/_bazel_hp/a7dace51e7355e...
# 259   15993                                          Fix typos
# 260   15991         Hide MSVC workaround from Clang on Windows
# 261   15989      Fix freeze_graph command line argument error.
# 262   15988  Add internal release notes that were previousl...
# 263   15987  Documentation for placeholder does not explain...
# 264   15986  Add new internal release notes that were misse...
# 265   15985  Feature Request: Dense to Sparse and Dense to ...
# 266   15983   Feature request: Reduce learning rate on plateau
# 267   15981  tf.Estimator creates loss and loss_1 for eval/...
# 268   15980       While loop randomly doesn't evaluate tensors
# 269   15979                                   Branch 181341793
# 270   15975  MKL: Fix for a compilation error caused by a p...
# 271   15974  Estimator.predict always loads model checkpoin...
# 272   15973  How to change the model, without any change in...
# 273   15972  Maven Version of tensorflow Java API jar wrong...
# 274   15968  Imperfect implementation of tf.losses.mean_pai...
# 275   15967  Make graph transform tool accessible via comma...
# 276   15964                            DownloadfileTask Failed
# 277   15961           Adding cuda_config.h to the pip package.
# 278   15960                                   Branch 181239691
# 279   15959  Adding an install sources line for 1.5.0-rc0. ...
# 280   15957  Switching branch and run ./configure does not ...
# 281   15955                                   Branch 181174976
#
#                                           labels  \
# 0                                       cla: yes
# 1                                            NaN
# 2                     stat:awaiting tensorflower
# 3                                            NaN
# 4         awaiting testing (then merge),cla: yes
# 5                                            NaN
# 6           stat:awaiting tensorflower,type:docs
# 7                                       cla: yes
# 8                                       cla: yes
# 9                                       cla: yes
# 10                                           NaN
# 11                                      cla: yes
# 12   stat:awaiting response,type:bug/performance
# 13                                           NaN
# 14                                           NaN
# 15                                      cla: yes
# 16                                           NaN
# 17                                      cla: yes
# 18                        stat:awaiting response
# 19                                           NaN
# 20                                      cla: yes
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                      cla: yes
# 25                    stat:awaiting tensorflower
# 26                                           NaN
# 27        awaiting testing (then merge),cla: yes
# 28        awaiting testing (then merge),cla: yes
# 29                    stat:awaiting tensorflower
# ..                                           ...
# 252       awaiting testing (then merge),cla: yes
# 253       awaiting testing (then merge),cla: yes
# 254       awaiting testing (then merge),cla: yes
# 255                                     cla: yes
# 256                                     cla: yes
# 257                       stat:awaiting response
# 258                                 type:support
# 259       awaiting testing (then merge),cla: yes
# 260       awaiting testing (then merge),cla: yes
# 261                     awaiting review,cla: yes
# 262                                     cla: yes
# 263                                    type:docs
# 264                                      cla: no
# 265      stat:contributions welcome,type:feature
# 266      stat:awaiting tensorflower,type:feature
# 267                                 type:support
# 268                   stat:awaiting tensorflower
# 269                                     cla: yes
# 270       awaiting testing (then merge),cla: yes
# 271                   stat:awaiting tensorflower
# 272                                          NaN
# 273                                          NaN
# 274                       stat:awaiting response
# 275                     awaiting review,cla: yes
# 276                       stat:awaiting response
# 277                                     cla: yes
# 278                                     cla: yes
# 279                                     cla: yes
# 280                           type:build/install
# 281                                     cla: yes
#
#                                                   body  assignees  milestone  \
# 0                              Fixed a couple of typos          0        NaN
# 1    ### System information\r\r\n- **Have I written...          0        NaN
# 2    ### System information\r\r\n- **Have I written...          0        NaN
# 3    ### System information\r\r\n- **Have I written...          0        NaN
# 4                                 Fixing markdown typo          0        NaN
# 5    Please go to Stack Overflow for help and suppo...          0        NaN
# 6    Go tot the page \r\r\nhttps://www.tensorflow.o...          1        NaN
# 7                                                  NaN          0        NaN
# 8    - [x] Fix build error\r\r\n- [x] Update test\r...          0        NaN
# 9                                                  NaN          0        NaN
# 10   I get this error message when trying to build ...          0        NaN
# 11   The link syntax was inverted, that is, round b...          0        NaN
# 12   ### System information\r\r\n- **Have I written...          0        NaN
# 13   How to install TF on banana m64? OS: Linux bpi...          0        NaN
# 14   ### System information\r\r\n- **Have I written...          0        NaN
# 15                              * Fix xcode path error          0        NaN
# 16   I use the batch norm layer like this:\r\r\n`de...          0        NaN
# 17     # C0330 bad-continuation\r\r\n  # C0301 line...          0        NaN
# 18   TF's  high level API  is very convenient to de...          1        NaN
# 19   My understanding is that paramenters of neural...          0        NaN
# 20                                                 NaN          0        NaN
# 21   This is a request for allowing to pass a dict ...          0        NaN
# 22   ### System information\r\r\n- **OS**:Windows 1...          0        NaN
# 23   ### System information\r\r\n- **Have I written...          0        NaN
# 24                                                 NaN          0        NaN
# 25   I am trying to run the DeepLab Resnet (https:/...          0        NaN
# 26   Dear all, \r\r\nI follow  post in "https://blo...          1        NaN
# 27                                                 NaN          0        NaN
# 28                                                 NaN          0        NaN
# 29   Please go to Stack Overflow for help and suppo...          0        NaN
# ..                                                 ...        ...        ...
# 252  An if/else statement was given inline as an ar...          0        NaN
# 253  Adding wrapped cell property as discussed in #...          1        NaN
# 254  ## Verbs implementation to use direct tensor w...          0        NaN
# 255                                                NaN          1        NaN
# 256  ```bash\r\r\n[07:05:58]\t[Step 1/1] In file in...          0        NaN
# 257  currently , I am working on loading and testin...          0        NaN
# 258  \r\r\n\r\r\n------------------------\r\r\n\r\r...          0        NaN
# 259  This PR fixes some typos: `refered`, `ouptuts`...          1        NaN
# 260                                             #15990          0        NaN
# 261  Fix TypeError: main() missing 1 required posit...          1        NaN
# 262  I wasn't sure about some of the Important/Othe...          0        NaN
# 263  ### System information\r\r\n\r\r\nNot necessar...          0        NaN
# 264                                                NaN          0        NaN
# 265  I think it would be helpful if there is a dens...          0        NaN
# 266  Please go to Stack Overflow for help and suppo...          0        NaN
# 267  - **OS Platform and Distribution (e.g., Linux ...          0        NaN
# 268  Hello!\r\r\nI believe to have found a bug in T...          0        NaN
# 269                                                NaN          0        NaN
# 270                                                NaN          1        NaN
# 271  ### System information\r\r\n- **OS Platform an...          0        NaN
# 272  Hello,\r\r\n\r\r\nI want to make an android ap...          0        NaN
# 273  ### System information\r\r\nHave I written cus...          1        NaN
# 274  ### System information\r\r\n- **TensorFlow ver...          1        NaN
# 275  RELNOTE: Make graph transform tool available f...          1        NaN
# 276  try projrct as https://www.tensorflow.org/mobi...          0        NaN
# 277                                                NaN          0        NaN
# 278                                                NaN          0        NaN
# 279
#  this for official.          0        NaN
# 280  When building from source with TensorFlow and ...          1        NaN
# 281                                                NaN          0        NaN
#
#      comments            created_at author_association          address_date
# 0           3  2018-02-03T18:42:26Z        CONTRIBUTOR  2018-02-03T18:48:31Z
# 1           1  2018-02-03T01:07:58Z        CONTRIBUTOR  2018-02-03T01:39:35Z
# 2           3  2018-02-02T20:29:29Z               NONE  2018-02-02T23:12:50Z
# 3           1  2018-02-02T15:19:12Z               NONE  2018-02-02T17:38:10Z
# 4           4  2018-02-02T10:10:12Z        CONTRIBUTOR  2018-02-02T10:12:07Z
# 5           1  2018-02-02T09:14:57Z               NONE  2018-02-02T18:52:08Z
# 6           4  2018-02-02T03:58:02Z               NONE  2018-02-02T18:44:40Z
# 7           1  2018-02-02T01:59:52Z             MEMBER  2018-02-02T02:02:15Z
# 8           2  2018-02-01T19:00:57Z             MEMBER  2018-02-02T00:54:42Z
# 9           1  2018-02-01T18:30:59Z             MEMBER  2018-02-01T18:57:50Z
# 10          9  2018-02-01T15:52:21Z               NONE  2018-02-01T16:51:44Z
# 11          4  2018-02-01T15:38:23Z        CONTRIBUTOR  2018-02-01T15:39:39Z
# 12          3  2018-02-01T13:04:29Z               NONE  2018-02-02T03:49:17Z
# 13          1  2018-02-01T12:14:54Z               NONE  2018-02-01T18:01:59Z
# 14         12  2018-02-01T10:38:27Z               NONE  2018-02-01T11:53:15Z
# 15          3  2018-02-01T10:24:43Z        CONTRIBUTOR  2018-02-01T10:31:45Z
# 16          1  2018-02-01T10:02:01Z               NONE  2018-02-02T02:10:41Z
# 17          1  2018-02-01T09:55:53Z             MEMBER  2018-02-01T10:22:31Z
# 18          5  2018-02-01T06:34:16Z               NONE  2018-02-02T02:08:28Z
# 19          1  2018-02-01T05:56:36Z               NONE  2018-02-01T18:02:23Z
# 20          3  2018-02-01T01:56:29Z             MEMBER  2018-02-01T01:57:15Z
# 21          5  2018-01-31T22:24:53Z               NONE  2018-01-31T23:00:57Z
# 22          2  2018-01-31T18:17:24Z               NONE  2018-01-31T19:05:22Z
# 23          1  2018-01-31T16:34:00Z               NONE  2018-01-31T19:24:53Z
# 24          1  2018-01-31T15:22:47Z        CONTRIBUTOR  2018-02-01T01:41:12Z
# 25          2  2018-01-31T11:59:09Z               NONE  2018-01-31T18:19:06Z
# 26          7  2018-01-31T10:23:42Z               NONE  2018-02-02T05:15:49Z
# 27          1  2018-01-31T03:08:35Z        CONTRIBUTOR  2018-01-31T15:25:25Z
# 28          1  2018-01-31T00:18:08Z        CONTRIBUTOR  2018-01-31T00:29:27Z
# 29          4  2018-01-30T22:19:50Z               NONE  2018-01-30T23:11:10Z
# ..        ...                   ...                ...                   ...
# 252         5  2018-01-10T13:05:09Z        CONTRIBUTOR  2018-01-11T02:33:39Z
# 253         7  2018-01-10T12:20:19Z        CONTRIBUTOR  2018-01-14T03:25:19Z
# 254         8  2018-01-10T12:15:07Z        CONTRIBUTOR  2018-01-10T12:18:11Z
# 255         9  2018-01-10T09:11:05Z        CONTRIBUTOR  2018-01-16T06:34:03Z
# 256         5  2018-01-10T07:55:45Z               NONE  2018-01-11T05:18:01Z
# 257         2  2018-01-10T05:53:51Z               NONE  2018-01-10T13:17:17Z
# 258         1  2018-01-10T03:41:02Z               NONE  2018-01-11T00:22:55Z
# 259         2  2018-01-10T02:59:48Z        CONTRIBUTOR  2018-01-11T02:15:41Z
# 260         2  2018-01-10T01:51:56Z        CONTRIBUTOR  2018-01-11T20:19:47Z
# 261         7  2018-01-10T00:12:56Z               NONE  2018-01-29T19:53:17Z
# 262         1  2018-01-09T23:45:17Z             MEMBER  2018-01-10T00:28:45Z
# 263         2  2018-01-09T23:28:05Z               NONE  2018-01-10T01:01:55Z
# 264         2  2018-01-09T23:22:48Z             MEMBER  2018-01-09T23:23:48Z
# 265        24  2018-01-09T23:19:33Z        CONTRIBUTOR  2018-01-10T00:56:54Z
# 266         4  2018-01-09T22:49:36Z               NONE  2018-01-11T00:48:57Z
# 267         4  2018-01-09T20:04:17Z               NONE  2018-01-10T00:07:50Z
# 268         6  2018-01-09T19:58:14Z               NONE  2018-01-11T03:02:39Z
# 269         2  2018-01-09T19:16:46Z             MEMBER  2018-01-09T19:16:57Z
# 270         5  2018-01-09T13:05:01Z        CONTRIBUTOR  2018-01-11T03:11:25Z
# 271         2  2018-01-09T12:56:34Z        CONTRIBUTOR  2018-01-10T00:21:20Z
# 272         4  2018-01-09T10:46:45Z               NONE  2018-01-09T19:01:48Z
# 273         5  2018-01-09T09:44:50Z               NONE  2018-01-09T19:01:44Z
# 274         2  2018-01-09T05:51:16Z        CONTRIBUTOR  2018-01-09T13:00:03Z
# 275         1  2018-01-09T05:23:56Z             MEMBER  2018-01-23T21:41:49Z
# 276         2  2018-01-09T03:37:07Z               NONE  2018-01-09T12:59:53Z
# 277         2  2018-01-09T01:13:19Z             MEMBER  2018-01-11T01:24:09Z
# 278         2  2018-01-09T01:09:42Z             MEMBER  2018-01-09T01:10:13Z
# 279         3  2018-01-08T22:21:15Z             MEMBER  2018-01-08T23:36:06Z
# 280         3  2018-01-08T21:07:43Z             MEMBER  2018-01-11T01:39:12Z
# 281         4  2018-01-08T18:28:33Z             MEMBER  2018-01-08T18:28:49Z
#
# [282 rows x 10 columns]
