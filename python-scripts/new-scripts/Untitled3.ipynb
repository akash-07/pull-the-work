# %%
import priority as pr

# %%
pr.runTool()
# Out:
# [1] Welcome to Issue Prioritizer
# Enter csv filename to read issuestensorflow-issues.csv
# [2] Reading issues from csv file...
# [3] Data frame created.
# [4] Converting data frame to issue list...
# [5] Issue list created.
# [6]
# Specify Priority order as:
# 1. author association
# 2. date created
# 3. assignees
# 4. comments
# Enter 4 space separated intergers: 1 2 4 3
# [7] Sorting issues as per the priority...
# [8] Converting back to Data Frame...
# [9] Returning sorted issues...
#         assignees author_association  comments            created_at  \
# number
# 1539            0             MEMBER        20  2016-03-18T02:01:26Z
# 4386            1             MEMBER         4  2016-09-14T17:13:20Z
# 4638            1             MEMBER        26  2016-09-28T21:16:49Z
# 4639            1             MEMBER         4  2016-09-28T21:18:29Z
# 6360            1             MEMBER        45  2016-12-16T13:45:13Z
# ...
