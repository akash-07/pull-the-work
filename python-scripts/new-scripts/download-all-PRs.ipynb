# %%
import pullRequests as pr
import utilities as ut
import recRetrieve as rec
url = rec.default_url
params = ut.getParams()
params['state'] = 'closed'

# %%
params
# Out:
# {'access_token': '26e3f7340239e28acf3a2a1b79736f6f5d81ee9a',
#  'per_page': 100,
#  'state': 'closed'}

# %%
rec.retrieve(url, params, pr.action)
# Out:
# Retrieving: https://api.github.com/repos/tensorflow/tensorflow/pulls?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=closed
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16305?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add LINM (Loop Invariant Node Motion) optimization pass in GraphOptim…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16299?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182808673
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16297?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Fix convolutional_recurrent_test failure
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16296?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Fixed convolutional_recurrent_test
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16295?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182802058
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16292?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182783262
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16286?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Removes redundant variable assignment
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16280?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Repair compilation error of tensorflow built with MKL-DNN
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16275?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: minor spelling tweaks for lite docs
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16274?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: R1.4
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16273?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add test for float16 support with conv1d and update docstring
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16270?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: udacity assignment 1 & 2
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16252?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182576952
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16250?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182559534
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16249?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182554969
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16245?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182511847
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16243?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16242?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16236?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182474037
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16233?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182456096
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16229?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Docker patch 14
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16224?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Suppress AWS curl init warning
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16223?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixing a typo for the argument to docker push. (#16204)
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16222?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182384458
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16217?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Windows: Add missing dependencies in lib_proto_parsing
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16212?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16211?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182305106
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16204?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixing a typo for the argument to docker push.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16201?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182280342
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16200?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Accepts `PathLike` objects for `model_dir`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16199?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182265266
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16196?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix issue of branch switching not working with bazel
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16195?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixing deprecated URL link
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16191?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix docstring typo of losses_impl.py
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16183?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: `AssignVariableOp` supports `DT_BFLOAT16`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16176?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: 4d55397500 patch 1
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16172?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Merge changes from r1.5 into master
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16171?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Updating the docker login command. The email flag is deprecated.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16169?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 182086883
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16158?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: GAN model: move generated and real operations under discriminator namespace
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16157?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update rules_closure to fix bazel version check
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16153?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: New features: tf.alphas and tf.alphas_like - Related to #16128
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16141?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: FIX Typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16140?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16130?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix broken python3 build
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16127?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix default parameters for TimeFreqLSTMCell, fixes #16100
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16125?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disable stacktrace_handler_test becase stack trace isn't generated on Windows
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16122?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16107?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: R1.5
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16099?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make srcd in variable
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16096?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Address bad merge in Java install instructions
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16092?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181814918
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16090?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL-DNN:  fix batchnorm unit test failures
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16089?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disable flaky model_analyzer_test on windows.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16088?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disable keras data_utils_test as it's flaky.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16086?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Intel MKL-DNN] fixes for several MKLDNN unit tests.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16081?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL-DNN: fix concat issue related to negative input concat_dim
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16080?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL-DNN: fix a concat issue which is related to negative concat_dim
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16079?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181765083
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16078?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update important RELNOTES and author list
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16077?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update LICENSE
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16074?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16071?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix comments and code matches
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16070?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16067?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [XLA] Separate out the dynamic slice wrapping tests
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16066?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: the loss is nan
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16060?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181679271
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16059?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Intel MKL] Fixes for various MKLDNN unit test failures
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16056?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Apply 1.5-rc1 cherry-picks.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16055?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Fixed 3 bugs picked up by the unit tests
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16049?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Windows: Batch script for building the CUDA-enabled C library.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16047?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181629980
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16043?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix C2678 error on VS2017 15.5
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16037?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Windows: Remove -j option when zip libtensorflow package
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16030?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Use https for `https://github.com/tensorflow/serving`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16029?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update embedding.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16027?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: py2tf: add py2tf_internal BUILD rule to pip package
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16024?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: R1.4
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16022?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update version strings and revert pom.xml changes
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16021?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update version strings.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16020?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Fix LRN tensor shape when Eigen path is taken.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16018?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181499300
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16017?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disable all failing tests to fix TF opensource tests.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16016?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disabling the warnings test for python3.5 as well.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16015?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Modify `_parse_bazel_version` to return a tuple of ints
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16013?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Disabling the interleave_op_test for now.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16007?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix inline if/else statement in CMAKE_CACHE_ARGS
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16005?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Verbs w 0 copies
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/16002?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix a_ to allocator_
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15993?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typos
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15991?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Hide MSVC workaround from Clang on Windows
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15988?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add internal release notes that were previously missing.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15986?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add new internal release notes that were missed in the previous iteration.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15984?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix r1.5 tests.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15979?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181341793
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15975?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Fix for a compilation error caused by a previous commit
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15970?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix local path for hexagon_graph_execution in sample script
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15961?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Adding cuda_config.h to the pip package.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15960?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181239691
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15959?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Adding an install sources line for 1.5.0-rc0. Earlier we only updated…
# Storing data in tensorflow.csv
# Limit Remaining: 4452
# Retrieving: https://api.github.com/repositories/45717250/pulls?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=closed&page=2
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15955?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 181174976
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15950?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update 1_notmnist.ipynb
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15947?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Windows: Override /DEIGEN_STRONG_INLINE=inline for //tensorflow/core/kernels:conv_ops
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15944?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix tensorflow::CurrentStackTrace when TF_GENERATE_BACKTRACE isn't defined
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15928?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Utility classes for writing Java source code from a C++ process (part 2)
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15927?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: R1.5/verbs w 0 copies
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15923?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add clean_dep to copts macro.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15922?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add clean_dep to a bazel macro.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15918?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add pos_weights practical interpretation
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15917?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update docs for `concat` in case `axis < 0`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15901?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180993147
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15899?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Addresses S3 timeout configurability discussed in #15868
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15898?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: DO NOT MERGE YET: Cuda config
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15895?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Use https for `www.tensorflow.org`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15888?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Cleanup CocoaPods dependency from TFLite iOS examples
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15885?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Deletes unnecessary lines of code
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15884?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add release note: sparse tensors in `tf.data`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15881?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix a few pip tests
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15879?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Removing twice times declared same statement in Java_org_tensorflow_Operation_shape function
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15878?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Windows: Release script for C library GPU builds on Windows
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15875?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix the comments which mistake x for y in gradient_checker
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15867?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180856860
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15865?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: extract populate weight collection.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15864?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix docs
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15863?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo in eager value_and_gradients docstring
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15862?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: extract populate weight collection.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15860?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180746153
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15857?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update documentation for gather_nd/gather to specify behaviors for out-of-bound indices
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15856?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL DNN: Implementing MKL DNN version of Softmax
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15854?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enable tilde expansion in debug wrappers
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15853?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixes and formatting to configure.py
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15843?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: WIP: LSTMBlockFusedCell supports Dropout
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15842?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Windows: Disable bfloat16_test and framework_dtypes_test
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15836?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add axis support for `tf.nn.crelu`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15829?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [Bazel/Windows] Wrap rm -rf in Bash for Windows (and some refactoring)
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15828?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Merging 1.5.0-rc0 back to master.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15826?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove :0 in final result argument
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15825?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update advise.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15820?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "Remove unneeded branch check (#13495)"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15819?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "Fix a bug: bfloat16 is unsigned on Windows (#15302)"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15814?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix git configuration on Windows
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15813?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo in UserInputError()
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15812?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Closing input stream, runner session in TensorFlowInferenceInterface.java and fixing bit changes
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15811?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo in LinearModel() docstring
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15808?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove noop python command in pyx_library rule.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15807?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix unstable test case for Select op
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15803?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Memory allocation improvement for `decode_libsvm`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15799?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixing the item_test failure.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15798?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix docs to recommend cuDNN 6.0, rather than the old 5.1 or non-exist…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15797?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Change dso_loader to look for libcupti.so instead of libcupti.so.8.0
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15796?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix build issues with cuda 9.1 through updating eigen.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15794?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix kmeans gpu and upgrading TF base images to 16
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15790?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: order quantized table by value for ease of reading
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15789?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: order quantized table by value for ease of reading
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15787?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: order quantized table by value for ease of reading
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15780?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [configure] eagerly determine the truthfulness of environment variables
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15775?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: R1.2
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15774?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix invalid Markdown in docstring
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15772?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: remove trailing semicolon at the end of line
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15765?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Trivial python syntax fixes
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15764?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "C++ gradient for Select (#14862)"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15763?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180441903
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15762?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Make unused variable warning an error during TF builds.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15761?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "add c++ gradient for op: Pow (#15245)"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15759?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update license year
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15757?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixes #15736
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15756?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixes #15736
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15750?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [XLA] Fix std::array initialization take 2
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15749?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [XLA] Define TF_COMPILE_LIBRARY for two libraries
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15748?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [XLA] Add missing win header deps to framework_lite
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15742?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Use Eigen version of the `scalar_pow_op` for `pow` ops
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15740?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Simplify the dense_to_one_hot method
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15739?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix the headers error due to recent CUDA9.1 change
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15734?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15719?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixed a typo for CreateBody()
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15718?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: update mkldnn to the latest release
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15714?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Optimizing code and adding from http to https
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15713?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: getting latest pull
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15712?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Removing extra space, preventing double declared "if" statement and from http to https
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15711?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update estimator.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15710?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix doc `tf.data.contrib.map_and_batch` to `tf.contrib.data.map_and_batch`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15709?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update graphs.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15708?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Update estimator.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15707?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: updated the latest mkldnn
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15705?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: updated the latest mkldnn
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15704?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Used template version of SafeStringToNumeric to reduce code duplication
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15703?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180304271
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15702?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix out of memory issue on Tegra devices
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15700?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Cherrypicks
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15686?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix description of HASHTABLE_LOOKUP in smartreply doc
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15683?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: R1.4
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15680?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Improve doc of TFRecordDataset, shuffle ahead of map
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15678?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: De-Bazel pip_smoke_test sanity check
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15676?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enabling tests to pass with python3.6. Updating dependencies for dock…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15675?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180224227
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15674?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Remove third_party/ prefixes
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15673?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [README] Link to build history
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15670?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [CMake] Add sanity tests for python file lists
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15667?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: minor wording fix in (slim) readme
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15666?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: updated Readme.md
# Storing data in tensorflow.csv
# Limit Remaining: 4351
# Retrieving: https://api.github.com/repositories/45717250/pulls?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=closed&page=3
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15664?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix small typo in docstring which causes the API doc to render incorr…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15663?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "Fix a bug: bfloat16 is unsigned on Windows (#15302)"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15661?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo 'updaye' in audio_recognition.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15658?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: add a function to add extra logging handler
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15657?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Removed misplaced quote char
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15654?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Enable `axis` support for `tf.unique`
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15653?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Clarify batch_norm documentation to highlight that the dimensions for…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15652?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix variable name
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15648?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Predictor fixes for core estimators
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15646?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180147476
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15637?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix an lib error while building with CUDA9.1
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/15632?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 180053468
# ...
# Working on pull request titled: Fix license declaration for Python headers
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14468?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Added Ubuntu 16.04 Dockerfile with TF 1.4 optimized for CPU with Inte…
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14467?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix Python auto configure build support
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14466?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add named contacts to Code of Conduct
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14465?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix a stray hyphen and add an SO link
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14464?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "Branch 175277161"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14463?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: added CMake options to provide external zlib, GRPC, Eigen
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14461?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Sync Branch 175311543
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14459?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Adding Batch Normalization implementation using the open source MKL-DNN Lib
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14458?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Adding Concat op implementation using the open source MKL_DNN
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14457?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: MKL: Adding Relu implementation using the open source MKL-DNN
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14453?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Branch 175277161
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14447?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: PrefetchDataset with buffer_size==0 results in deadlock
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14443?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: fix the distributed training problem for the estimator api
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14440?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: code comments error in docker notebook
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14439?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix all tests under python/keras on windows
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14438?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: code comments error in docker notebook
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14437?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14435?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14434?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixed typo in tfprof
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14431?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: typo fixed
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14427?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: golang: ~2x speedup for encodeTensor()
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14426?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix absl flag initialization in cloud_tpu_profiler
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14424?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo <Copybara Experiment DO NOT MERGE>
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14422?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Add the C++ gradient of the Prod operation.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14421?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: [iOS] Add optional Selective Registration of Ops
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14420?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix allow_smaller_final_batches for bucket_by_sequence_length.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14419?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Replace the docker check with an OS check.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14418?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: enum34 is only required for Python < 3.4
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14412?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo. <Copybara Experiment DO NOT MERGE>
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14411?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "golang: ~2x speedup for encodeTensor()"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14409?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: added patch needed for jetson tx2/1
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14408?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix Jenkins build error (`//tensorflow/go:test`) on HEAD
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14404?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix a build error in windows debug build
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14403?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: modified convolution document
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14401?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: CMake: configure default string values of options properly
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14399?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fixed typos in comments
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14397?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: remove duplicated code
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14395?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Installing TensorFlow for C
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14390?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: `variable_scope` use `auxiliary_name_scope` to control whether to create new name scope
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14389?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Forward declare condition_variable, fix for #14388
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14386?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo <Copybara Experiment DO NOT MERGE>
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14385?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: golang: added Session.ListDevices method
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14383?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Revert "[OpenCL SYCL] Add support for triSYCL in TensorFlow"
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14382?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Looks like an rc1 string got into master. Here is the fix.
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14379?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix sycl BUILD bazel syntax error
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14378?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix typo. <Copybara Experiment DO NOT MERGE>
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14377?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix indenting on cache check in Network layer class
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14376?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Typo fixed in RELEASE.md
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14372?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: golang: added Session.ListDevices method
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14371?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix #14324 and another compile error with mkl
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14370?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Change `NHWC`/`NCHW` to `NWC`/`NCW` for conv1d
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14368?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: golang: ~2x speedup for encodeTensor()
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14367?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: golang: added Session.ListDevices method
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14362?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: 在Windows上安装TensorFlow
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14354?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Fix estimator convert from Keras to export_savedmodel() #14284
# url for this pull_req: https://api.github.com/repos/tensorflow/tensorflow/pulls/14350?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on pull request titled: Bag of words
# Storing data in tensorflow.csv
# ---------------------------------------------------------------
# UnicodeEncodeError            Traceback (most recent call last)
# <ipython-input-8-831faa0d66f3> in <module>()
# ----> 1 rec.retrieve(url, params, pr.action)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\recRetrieve.py in retrieve(url, params, action, first_page)
#      36         if(pointers[i] == 'next'):
#      37             url = links[i]
# ---> 38             return retrieve(url, {}, action,False)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\recRetrieve.py in retrieve(url, params, action, first_page)
#      36         if(pointers[i] == 'next'):
#      37             url = links[i]
# ---> 38             return retrieve(url, {}, action,False)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\recRetrieve.py in retrieve(url, params, action, first_page)
#      36         if(pointers[i] == 'next'):
#      37             url = links[i]
# ---> 38             return retrieve(url, {}, action,False)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\recRetrieve.py in retrieve(url, params, action, first_page)
#      36         if(pointers[i] == 'next'):
#      37             url = links[i]
# ---> 38             return retrieve(url, {}, action,False)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\recRetrieve.py in retrieve(url, params, action, first_page)
#      36         if(pointers[i] == 'next'):
#      37             url = links[i]
# ---> 38             return retrieve(url, {}, action,False)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\recRetrieve.py in retrieve(url, params, action, first_page)
#      36         if(pointers[i] == 'next'):
#      37             url = links[i]
# ---> 38             return retrieve(url, {}, action,False)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\recRetrieve.py in retrieve(url, params, action, first_page)
#      22     headers = str(connection.info())
#      23     data = connection.read().decode()
# ---> 24     action(data,first_page)
#      25     #print(headers)
#      26     links = re.findall(r'<(.+?)>', headers)
#
# F:\Study-Ebooks\Sem-6\PSE-Lab\python-scripts\new-scripts\pullRequests.py in action(data, first_page)
#      32         writer.writeheader()
#      33     for row in rowdata:
# ---> 34         writer.writerow(row)
#      35     csv_file.close()
#
# c:\users\user\miniconda3\lib\csv.py in writerow(self, rowdict)
#     153
#     154     def writerow(self, rowdict):
# --> 155         return self.writer.writerow(self._dict_to_list(rowdict))
#     156
#     157     def writerows(self, rowdicts):
#
# c:\users\user\miniconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u5728' in position 1: character maps to <undefined>

# %%
import pandas as pd
df = pd.read_csv('tensorflow.csv', encoding = 'latin-1')

# %%
df
# Out:
#                                                  title  commits  additions  \
# 0    Add LINM (Loop Invariant Node Motion) optimiza...        2        647
# 1                                     Branch 182808673        5        686
# 2        MKL: Fix convolutional_recurrent_test failure        1          1
# 3              MKL: Fixed convolutional_recurrent_test        1          1
# 4                                     Branch 182802058        6        420
# 5                                     Branch 182783262       24       1587
# 6                Removes redundant variable assignment        1          0
# 7    Repair compilation error of tensorflow built w...        1          1
# 8                  minor spelling tweaks for lite docs        1          3
# 9                                                 R1.4       76       2986
# 10   Add test for float16 support with conv1d and u...        3         24
# 11                            udacity assignment 1 & 2        1       1667
# 12                                    Branch 182576952       18       2568
# 13                                    Branch 182559534       11       2149
# 14                                    Branch 182554969        7        104
# 15                                    Branch 182511847       35        815
# 16                                            fix typo        1          2
# 17                                            fix typo        1          1
# 18                                    Branch 182474037       33        810
# 19                                    Branch 182456096       29       2404
# 20                                     Docker patch 14        3         36
# 21                      Suppress AWS curl init warning        1          1
# 22   Fixing a typo for the argument to docker push....        1          1
# 23                                    Branch 182384458       21       5323
# 24   Windows: Add missing dependencies in lib_proto...        1          1
# 25                                            fix typo        1          1
# 26                                    Branch 182305106       16       3139
# 27      Fixing a typo for the argument to docker push.        1          1
# 28                                    Branch 182280342        6        189
# 29          Accepts `PathLike` objects for `model_dir`        3         28
# ..                                                 ...      ...        ...
# 570       `mean_relative_error` supports complex label        2         26
# 571    Use cub::ReduceByKey to count partition indices        2        247
# 572                                         typo fixed        0          0
# 573                                      little_modify        1          1
# 574  Use the known fixed size of the tensor array i...        1          2
# 575  [XLA] Fix build issue with TensorShape constru...        1          2
# 576                        Move ptr_util to core/util.        3        100
# 577       [Java] Add support for shape list attributes        1        110
# 578                     Fix up link to ios.md in docs.        1          1
# 579                                   Branch 176031889       27       1997
# 580          Add LICENSES to gitignore for iOS example        1          3
# 581                            macOS doesn't have wget        2          9
# 582  Disable for generated_examples_zip_test in ope...        2          1
# 583          1.4.1 patch release update version string        1         36
# 584  Fixing download_dependencies.sh bugs for gener...        3          5
# 585                                   Branch 175983704      105      12790
# 586                                   Simplify imports        2          1
# 587                                               R1.4       63       2732
# 588                                  Fix the mac build        1          1
# 589  [Speech commands] Add `num_classes=label_count...        1          1
# 590         Add compression support for TextLineReader        4        102
# 591                             Disable slice_op_test.        2          9
# 592            iOS Camera example for TensorFlow Lite.        1       1168
# 593                             typo: s/cesnus/census/        1          1
# 594                                Fix MPI compilation        1          1
# 595                 Changed ffmpeg verbosity semantics        1          4
# 596                          Add LayerNormBasicGRUCell        1        174
# 597                   minor spelling tweaks in headers        1          2
# 598  Converting the real and imaginary float values...        2         14
# 599             Added mode to input function arguments      158      16356
#
#      deletions  changed_files author_association
# 0            0              6               NONE
# 1           84             15             MEMBER
# 2            1              1        CONTRIBUTOR
# 3            1              1               NONE
# 4           49             12        CONTRIBUTOR
# 5          240             61             MEMBER
# 6            1              1        CONTRIBUTOR
# 7            1              1        CONTRIBUTOR
# 8            3              2        CONTRIBUTOR
# 9         1244             83               NONE
# 10          22              2             MEMBER
# 11           0              2               NONE
# 12         295             32             MEMBER
# 13         197             20             MEMBER
# 14          22             11             MEMBER
# 15          65             20             MEMBER
# 16           2              2        CONTRIBUTOR
# 17           1              1        CONTRIBUTOR
# 18          60             19             MEMBER
# 19        1024            100             MEMBER
# 20           1              1             MEMBER
# 21           0              1             MEMBER
# 22           1              1             MEMBER
# 23        1109            138             MEMBER
# 24           0              1             MEMBER
# 25           1              1        CONTRIBUTOR
# 26         646            104             MEMBER
# 27           1              1             MEMBER
# 28          12              9             MEMBER
# 29           5              4        CONTRIBUTOR
# ..         ...            ...                ...
# 570         11              2        CONTRIBUTOR
# 571         67              3        CONTRIBUTOR
# 572          0              0        CONTRIBUTOR
# 573          1              1               NONE
# 574          1              1        CONTRIBUTOR
# 575          2              1        CONTRIBUTOR
# 576         40              6              OWNER
# 577          2              4        CONTRIBUTOR
# 578          1              1        CONTRIBUTOR
# 579       1488             80              OWNER
# 580          0              1        CONTRIBUTOR
# 581          4              1        CONTRIBUTOR
# 582          0              1              OWNER
# 583         36              8             MEMBER
# 584          2              3        CONTRIBUTOR
# 585       5448            343              OWNER
# 586         17              1               NONE
# 587       1169             73               NONE
# 588          1              1              OWNER
# 589          1              1        CONTRIBUTOR
# 590         19              4             MEMBER
# 591          0              2              OWNER
# 592          2             12        CONTRIBUTOR
# 593          1              1        CONTRIBUTOR
# 594          0              1        CONTRIBUTOR
# 595          2              1        CONTRIBUTOR
# 596          0              2               NONE
# 597          2              2        CONTRIBUTOR
# 598          0              1        CONTRIBUTOR
# 599       7094            456             MEMBER
#
# [600 rows x 6 columns]

# %%
df1 = pd.read_csv('tensorflow-500.csv', encoding = "latin-1")

# %%
df1
# Out:
#                                                  title  commits  additions  \
# 0    Add LINM (Loop Invariant Node Motion) optimiza...        2        647
# 1                                     Branch 182808673        5        686
# 2        MKL: Fix convolutional_recurrent_test failure        1          1
# 3              MKL: Fixed convolutional_recurrent_test        1          1
# 4                                     Branch 182802058        6        420
# 5                                     Branch 182783262       24       1587
# 6                Removes redundant variable assignment        1          0
# 7    Repair compilation error of tensorflow built w...        1          1
# 8                  minor spelling tweaks for lite docs        1          3
# 9                                                 R1.4       76       2986
# 10   Add test for float16 support with conv1d and u...        3         24
# 11                            udacity assignment 1 & 2        1       1667
# 12                                    Branch 182576952       18       2568
# 13                                    Branch 182559534       11       2149
# 14                                    Branch 182554969        7        104
# 15                                    Branch 182511847       35        815
# 16                                            fix typo        1          2
# 17                                            fix typo        1          1
# 18                                    Branch 182474037       33        810
# 19                                    Branch 182456096       29       2404
# 20                                     Docker patch 14        3         36
# 21                      Suppress AWS curl init warning        1          1
# 22   Fixing a typo for the argument to docker push....        1          1
# 23                                    Branch 182384458       21       5323
# 24   Windows: Add missing dependencies in lib_proto...        1          1
# 25                                            fix typo        1          1
# 26                                    Branch 182305106       16       3139
# 27      Fixing a typo for the argument to docker push.        1          1
# 28                                    Branch 182280342        6        189
# 29          Accepts `PathLike` objects for `model_dir`        3         28
# ..                                                 ...      ...        ...
# 470  Adapt identity initializer API to other initia...        2         23
# 471                                   Branch 176732156       16        778
# 472                                   Branch 176791620       22        956
# 473                                   Branch 177033313       32       1805
# 474            golang: ~15x speedup for decodeTensor()        1         29
# 475         add extra document to parameter:num_epochs        1          3
# 476  Replace sys.maxint with sys.maxsize in learnin...        0          0
# 477     TensorBoard Modifications for Word2Vec Example        3         85
# 478                                    Create new_file        1          1
# 479                                          Fix typos        5          8
# 480                                          fix typos        2          4
# 481                     Update tf_core_framework.cmake        1          1
# 482  [XLA] FIX XLA/tfcompile on OSX. #if Guard AVX,...        1         40
# 483                                               R1.4       71       2948
# 484     Add collection parameter into built-in runners        1         81
# 485  Add uint32 and uint64 support for `bitwise_and...        6         25
# 486                                Format AUTHORS file        1          1
# 487                          Restore CONTRIBUTORS file        3         69
# 488        Some PATH typo : no `train_dir` in tutorial        1          4
# 489             [CMake] Extract list of python modules        5        505
# 490       tf.Print converts Variable to mutable Tensor        5         52
# 491               fix overpadding in MixtureSameFamily        1          4
# 492               fix overpadding in MixtureSameFamily        0          0
# 493                change bazel-mirror to mirror.bazel        2          3
# 494                change bazel-mirror to mirror.bazel        7          2
# 495                change bazel-mirror to mirror.bazel        4          2
# 496                            C++ gradient for Select        5         26
# 497                  min_quantize lib and command line        0          0
# 498                  Enable GCS filesystem for Windows        1         91
# 499            Add batch support for various image_ops        0          0
#
#      deletions  changed_files author_association
# 0            0              6               NONE
# 1           84             15             MEMBER
# 2            1              1        CONTRIBUTOR
# 3            1              1               NONE
# 4           49             12        CONTRIBUTOR
# 5          240             61             MEMBER
# 6            1              1        CONTRIBUTOR
# 7            1              1        CONTRIBUTOR
# 8            3              2        CONTRIBUTOR
# 9         1244             83               NONE
# 10          22              2             MEMBER
# 11           0              2               NONE
# 12         295             32             MEMBER
# 13         197             20             MEMBER
# 14          22             11             MEMBER
# 15          65             20             MEMBER
# 16           2              2        CONTRIBUTOR
# 17           1              1        CONTRIBUTOR
# 18          60             19             MEMBER
# 19        1024            100             MEMBER
# 20           1              1             MEMBER
# 21           0              1             MEMBER
# 22           1              1             MEMBER
# 23        1109            138             MEMBER
# 24           0              1             MEMBER
# 25           1              1        CONTRIBUTOR
# 26         646            104             MEMBER
# 27           1              1             MEMBER
# 28          12              9             MEMBER
# 29           5              4        CONTRIBUTOR
# ..         ...            ...                ...
# 470          0              3               NONE
# 471        236             31             MEMBER
# 472        269             42             MEMBER
# 473        597            142             MEMBER
# 474          0              2        CONTRIBUTOR
# 475          1              1        CONTRIBUTOR
# 476          0              0        CONTRIBUTOR
# 477         19              1        CONTRIBUTOR
# 478          0              1               NONE
# 479          8              6        CONTRIBUTOR
# 480          4              3        CONTRIBUTOR
# 481          1              1        CONTRIBUTOR
# 482         11              4        CONTRIBUTOR
# 483       1241             81               NONE
# 484         35              1               NONE
# 485         16              7             MEMBER
# 486          1              1        CONTRIBUTOR
# 487          0              1        CONTRIBUTOR
# 488          4              1        CONTRIBUTOR
# 489        488              4        CONTRIBUTOR
# 490         24              7        CONTRIBUTOR
# 491          3              1        CONTRIBUTOR
# 492          0              0        CONTRIBUTOR
# 493          3              1               NONE
# 494          2              1               NONE
# 495          2              1               NONE
# 496          0              2        CONTRIBUTOR
# 497          0              0               NONE
# 498         16              9        CONTRIBUTOR
# 499          0              0        CONTRIBUTOR
#
# [500 rows x 6 columns]
