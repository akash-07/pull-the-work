# %%
import closed_issues as iss
import recRetrieve as rec
import utilities as ut

# %%
params = ut.getParams()

# %%
params['state'] = 'closed'

# %%
iss.action??

# %%
url = 'https://api.github.com/repos/tensorflow/tensorflow/issues'

# %%
rec.retrieve(url, params, iss.action)
# Out:
# Retrieving: https://api.github.com/repos/tensorflow/tensorflow/issues?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=closed
# [1] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16748?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix the Windows GPU build #2
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16748/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16748 ....
# [2] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16744?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix the Windows GPU build #2
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16744/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16744 ....
# [3] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16741?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Making the for_canonicalization_test only for py2 and 3
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16741/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16741 ....
# [4] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16739?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fixing the cuda and cudnn versions in 1.5 docs. (#16702)
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16739/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16739 ....
# [5] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16733?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: golang: added Session.ListDevices method (#14385)
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16733/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16733 ....
# [6] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16732?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Delete device_functions.h include.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16732/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16732 ....
# [7] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16731?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fixed a couple of typos
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16731/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16731 ....
# [8] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16729?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix the Windows GPU build
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16729/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16729 ....
# [9] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16728?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Disable win io utils test for windows
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16728/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16728 ....
# [10] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16727?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix Python3 crazy SessionTest.testReentryWithCApi failure.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16727/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16727 ....
# [11] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16726?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 184376425
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16726/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16726 ....
# [12] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16724?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: R1.6
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16724/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16724 ....
# [13] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16717?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Cherrypicks
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16717/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16717 ....
# [14] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16716?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Linker Tools Error encountered when use StepStats
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16716/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16716 ....
# [15] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16715?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 184352399
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16715/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16715 ....
# [16] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16713?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Add k8 to detection for when to use neon_tensor_utils.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16713/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16713 ....
# [17] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16712?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix spelling: change "invaild" to "invalid"
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16712/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16712 ....
# [18] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16710?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Removing the typo line.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16710/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16710 ....
# [19] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16709?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Revert "Update external protobuf codebase version for Windows cmake b…
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16709/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16709 ....
# [20] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16708?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix sanity
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16708/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16708 ....
# [21] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16707?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Can't initialize an all zero SparseTensor
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16707/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16707 ....
# [22] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16706?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Absl fix
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16706/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16706 ....
# [23] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16705?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Update Eigen library to 2355b229ea4c and fixes conv2d padding issue
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16705/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16705 ....
# [24] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16704?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Remove all_files rule from com_google_absl.BUILD
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16704/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16704 ....
# [25] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16702?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fixing the cuda and cudnn versions in 1.5 docs.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16702/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16702 ....
# [26] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16701?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Update version to 1.6.0-rc0.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16701/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16701 ....
# [27] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16700?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Revert "Updating the version to 1.6.0-rc0."
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16700/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16700 ....
# [28] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16699?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 184236409
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16699/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16699 ....
# [29] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16697?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: gcc: error: unrecognized command line option '--config=opt'
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16697/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16697 ....
# [30] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16695?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Padding algo is not working as doc says
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16695/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16695 ....
# [31] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16690?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: change to anchor link
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16690/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16690 ....
# [32] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16688?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: how to assign the GPU device using C++?
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16688/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16688 ....
# [33] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16687?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: [DO NOT MERGE] Testing
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16687/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16687 ....
# [34] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16686?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Is there still a math_ops.h
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16686/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16686 ....
# [35] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16685?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix a broken link in regression_examples.md
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16685/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16685 ....
# [36] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16684?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: The link for the  tutorial on Google's Tensorflow SyntaxNet  page  gives 404 error
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16684/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16684 ....
# [37] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16682?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: [Recommendation] Expose tensorflow/core/kernels/dataset.h in wheel file
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16682/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16682 ....
# [38] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16681?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Sync r1.6 to master HEAD
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16681/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16681 ....
# [39] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16680?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 184220615
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16680/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16680 ....
# [40] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16679?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: fix typo
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16679/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16679 ....
# [41] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16677?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Dear frinds
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16677/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16677 ....
# [42] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16676?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Convert unicode to six.string_types for python 3
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16676/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16676 ....
# [43] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16675?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix linter error in losses_impl.py
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16675/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16675 ....
# [44] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16674?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix sanity build
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16674/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16674 ....
# [45] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16673?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Compile libtensorflow on windows with AVX.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16673/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16673 ....
# [46] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16672?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Updating the version to 1.6.0-rc0.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16672/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16672 ....
# [47] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16671?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Release Notes for r1.6
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16671/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16671 ....
# [48] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16664?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Improve shape function of NonMaxSuppression
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16664/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16664 ....
# [49] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16662?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Current Bazel version is 0.10.0, expected at least 0.5.4
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16662/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16662 ....
# [50] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16661?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix "Define the model" link.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16661/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16661 ....
# [51] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16658?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Runtime Error with Qt GUI Application
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16658/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16658 ....
# [52] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16657?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Tensorflow on banana-pi m64
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16657/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16657 ....
# [53] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16654?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Bazel version comparison fails with bazel 0.10.0
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16654/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16654 ....
# [54] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16653?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix docs
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16653/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16653 ....
# [55] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16652?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: v1.3 batch_norm layer
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16652/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16652 ....
# [56] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16651?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Temporarily remove three linter checks for now.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16651/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16651 ....
# [57] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16650?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix do_cmake_python_sanity error.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16650/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16650 ....
# [58] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16649?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: fix python 2.7 build break & import error on windows
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16649/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16649 ....
# [59] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16647?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Address sanity build issues.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16647/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16647 ....
# [60] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16646?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: can tf.estimator.Estimator's  parameters be modified by hand?
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16646/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16646 ....
# [61] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16645?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: What's the difference between Univariate prediction and Multivariate prediction?
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16645/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16645 ....
# [62] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16644?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: clear
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16644/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16644 ....
# [63] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16643?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Resolve pylint issues in image ops
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16643/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16643 ....
# [64] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16640?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Support multiple build types in Android build.gradle with the makefile build
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16640/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16640 ....
# [65] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16637?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 184052073
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16637/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16637 ....
# [66] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16636?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Add relnote about bug in ptxas in CUDA 9 and 9.1.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16636/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16636 ....
# [67] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16635?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Update ISSUE_TEMPLATE.md
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16635/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16635 ....
# [68] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16633?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Update docs for tf.matching_files to mention non-deterministic
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16633/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16633 ....
# [69] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16632?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Re-add missing argument specifier in build_all_android.sh
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16632/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16632 ....
# [70] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16631?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Allow variable_overwrites on scope level
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16631/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16631 ....
# [71] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16630?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Replace 'Dan' with 'Dandelion' in the citations
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16630/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16630 ....
# [72] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16628?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Tensorflow switches to CPU when using Variable.assign
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16628/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16628 ....
# [73] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16626?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: example script multivariate.py throws "UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape.  This may consume a large amount of memory."
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16626/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16626 ....
# [74] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16625?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: [For Test; DO NOT MERGE] Add grpcio as a pip dependency of tensorflow
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16625/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16625 ....
# [75] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16621?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Using tf.train.SyncReplicasOptimizer with multiple optimizers
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16621/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16621 ....
# [76] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16620?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: How to use model.summary() when using placeholder instead of Input(keras)
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16620/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16620 ....
# [77] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16614?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: AttributeError: module 'tensorflow' has no attribute 'keras'
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16614/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16614 ....
# [78] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16612?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Simplify loader_impl.py logic around main Op Tensor.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16612/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16612 ....
# [79] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16610?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fixed typo
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16610/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16610 ....
# [80] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16607?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: MKL: Pooling and AddN bug fixes
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16607/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16607 ....
# [81] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16605?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Description in docs of one-hot vector for mnist deep example confusing and/or wrong
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16605/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16605 ....
# [82] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16604?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 183881907
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16604/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16604 ....
# [83] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16602?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Remove query_layer in LuongMonotonicAttention
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16602/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16602 ....
# [84] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16600?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Moving code using new in the linear algebra kernels to absl::make_unique. This should make cleaning…
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16600/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16600 ....
# [85] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16599?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 183846994
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16599/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16599 ....
# [86] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16598?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Merge in final changes from the r1.5 branch
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16598/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16598 ....
# [87] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16597?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 183846994
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16597/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16597 ....
# [88] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16596?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Merge pull request #1 from tensorflow/master
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16596/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16596 ....
# [89] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16595?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 183846994
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16595/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16595 ....
# [90] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16591?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix FutureWarning on issubdtype from float to np.floating
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16591/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16591 ....
# [91] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16587?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Feature deprecated in h5py is used in TF1.5
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16587/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16587 ....
# [92] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16586?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Force sorting of CUDA/Python headers to avoid spurious rebuilds
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16586/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16586 ....
# [93] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16585?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: TensorFlow with CUDA or Python might rebuilds more than necessary instead of re-using bazel cache
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16585/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16585 ....
# [94] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16584?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: TensorFlow op to copy weights of Keras model
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16584/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16584 ....
# [95] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16583?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix typo
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16583/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16583 ....
# [96] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16578?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Different result between python and C++ with same pb file and same data.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16578/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16578 ....
# [97] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16577?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: By default, only download inception if it doesn't exist already
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16577/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16577 ....
# [98] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16575?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: There's no problem running on window, and there's a problem on Ubuntu
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16575/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16575 ....
# [99] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16574?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: tf.contrib.metrics.streaming_precision raise an exception Attempting to use uninitialized value model/precision/true_positives/count
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16574/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16574 ....
# [100] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16573?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Remove duplicated identical lines
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16573/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16573 ....
# Storing data in tensorflow-issues-closed1.csv
# Caught an exception. Continuing now....
# Limit Remaining: 4993
# Retrieving: https://api.github.com/repositories/45717250/issues?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a&state=closed&page=2
# [1] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16570?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix typos.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16570/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16570 ....
# [2] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16569?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled:  Support optionally passing mode to GANEstimator `discriminator_fn`.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16569/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16569 ....
# [3] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16565?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Feature Request: Separated Name Spaces of RNN Cells for hidden weights and recurrent states
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16565/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16565 ....
# [4] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16563?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Minor refactor to remove redundant test class
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16563/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16563 ....
# [5] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16562?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix typo
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16562/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16562 ....
# [6] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16559?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled:  Fixed iOS build script for all architectures, fixes #12904
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16559/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16559 ....
# [7] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16558?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Update README.md
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16558/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16558 ....
# [8] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16557?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: MKL: Fix for mkl_input conversion for MKL DNN.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16557/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16557 ....
# [9] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16556?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: tf.argmax appears to be functioning incorrectly on occasion
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16556/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16556 ....
# [10] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/16551?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 183683856
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/16551/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 16551 ....
# ...
# Looking at comments of issue numbered 15399 ....
# [3] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15398?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Feature request: tf.info to show docstrings in jupyter notebook
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15398/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15398 ....
# [4] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15397?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Tensorflow c++ memory leak - Valgrind
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15397/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15397 ....
# [5] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15394?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix typo of tf.abs docstring
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15394/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15394 ....
# [6] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15391?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: tf.nn.leaky_relu does not work with float64
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15391/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15391 ....
# [7] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15390?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Update C API test data comparison for s390x
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15390/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15390 ....
# [8] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15389?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fatal error while compiling Tensorflow with CUDA 9.1
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15389/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15389 ....
# [9] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15388?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: cannot install with virtualenv python3.6
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15388/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15388 ....
# [10] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15386?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix api usage in examples of GAN
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15386/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15386 ....
# [11] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15383?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Feature request: Use placeholders to specify the inputs of TFGAN model.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15383/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15383 ....
# [12] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15381?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: CMake: fix -fPIC control.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15381/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15381 ....
# [13] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15380?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: CMake: external package: PIC option not working
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15380/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15380 ....
# [14] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15378?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix PEP8
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15378/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15378 ....
# [15] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15377?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Add description for new PR workflow.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15377/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15377 ....
# [16] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15376?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: With tf-nightly-gpu, getting error: ImportError: /lib/x86_64-linux-gnu/libm.so.6: version `GLIBC_2.23' not found
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15376/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15376 ....
# [17] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15375?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Performance  problem TF VS Keras
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15375/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15375 ....
# [18] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15374?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: tf.matching_files order of returned files
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15374/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15374 ....
# [19] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15373?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: GPU memory usage changed from TF 1.3.0 to 1.4.0 - runs out of memory
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15373/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15373 ....
# [20] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15372?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Instead of "option" use "set" to define non-bool cmake build args.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15372/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15372 ....
# [21] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15371?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Standardize arguments in SessionRunHook APIs.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15371/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15371 ....
# [22] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15368?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Clean bazel `all_files` targets
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15368/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15368 ....
# [23] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15367?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: tf.keras.backend.set_learning_phase doesn't work during evaluating model
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15367/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15367 ....
# [24] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15365?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Automatic node placement (allocating graph nodes to multiple devices) feature  in distributed tensorflow
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15365/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15365 ....
# [25] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15363?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: how to feed a placeholder with the return values of tf.train.batch()
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15363/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15363 ....
# [26] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15362?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Fix broken image link in TensorFlow Lite's docs
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15362/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15362 ....
# [27] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15361?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: //tensorflow/python:bfloat16_test and //tensorflow/python:framework_dtypes_test failing on Windows
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15361/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15361 ....
# [28] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15359?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: code is jammed when evaluate
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15359/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15359 ....
# [29] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15358?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: how can I see the graphs in tensorboard?
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15358/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15358 ....
# [30] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15357?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Could not find a version that satisfies the requirement tensorflow (from versions: )
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15357/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15357 ....
# [31] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15356?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 178996911
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15356/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15356 ....
# [32] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15355?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Dockerfile.devel-gpu: optimize the size of the generated image
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15355/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15355 ....
# [33] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15353?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: [Go]: Make op wrapper generation more robust.
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15353/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15353 ....
# [34] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15351?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: questions about shared variables between CPU and GPU
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15351/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15351 ....
# [35] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15350?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Branch 178965261
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15350/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15350 ....
# [36] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15349?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Revert "Add batch support for various image_ops (#14854)"
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15349/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15349 ....
# [37] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15348?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Benchmarks for flipping and random flipping
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15348/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15348 ....
# [38] url for this issue: https://api.github.com/repos/tensorflow/tensorflow/issues/15347?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Working on the issue titled: Object Detection frozen graph issue
# Comments url : https://api.github.com/repos/tensorflow/tensorflow/issues/15347/comments?per_page=100&access_token=26e3f7340239e28acf3a2a1b79736f6f5d81ee9a
# Looking at comments of issue numbered 15347 ....

# %%
import pandas as pd

# %%
df = pd.read_csv('tensorflow-issues-closed.csv', encoding = 'latin-1')

# %%
df
# Out:
#      number                                              title  \
# 0     16731                            Fixed a couple of typos
# 1     16716  Linker Tools Error encountered when use StepStats
# 2     16707          Can't initialize an all zero SparseTensor
# 3     16695            Padding algo is not working as doc says
# 4     16690                              change to anchor link
# 5     16688            how to assign the GPU device using C++?
# 6     16684  The link for the  tutorial on Google's Tensorf...
# 7     16680                                   Branch 184220615
# 8     16674                                   Fix sanity build
# 9     16672                 Updating the version to 1.6.0-rc0.
# 10    16662  Current Bazel version is 0.10.0, expected at l...
# 11    16661                       Fix "Define the model" link.
# 12    16658              Runtime Error with Qt GUI Application
# 13    16657                        Tensorflow on banana-pi m64
# 14    16654   Bazel version comparison fails with bazel 0.10.0
# 15    16653                                           Fix docs
# 16    16652                              v1.3 batch_norm layer
# 17    16651    Temporarily remove three linter checks for now.
# 18    16646  can tf.estimator.Estimator's  parameters be mo...
# 19    16645  What's the difference between Univariate predi...
# 20    16636  Add relnote about bug in ptxas in CUDA 9 and 9.1.
# 21    16631           Allow variable_overwrites on scope level
# 22    16628  Tensorflow switches to CPU when using Variable...
# 23    16626  example script multivariate.py throws "UserWar...
# 24    16625  [For Test; DO NOT MERGE] Add grpcio as a pip d...
# 25    16621  Using tf.train.SyncReplicasOptimizer with mult...
# 26    16620  How to use model.summary() when using placehol...
# 27    16612  Simplify loader_impl.py logic around main Op T...
# 28    16607                    MKL: Pooling and AddN bug fixes
# 29    16605  Description in docs of one-hot vector for mnis...
# ..      ...                                                ...
# 684   15179   Failure in LMDBReaderTest while reading testdata
# 685   15178  Dataset.from_generator doesn't play nice with ...
# 686   15175  Got "Attempting to use uninitialized value" er...
# 687   15174                                   Branch 178185697
# 688   15173                                     Fix for #12537
# 689   15171  [FeatureRequest] Decorator for estimator input_fn
# 690   15170       Go: Don't require -std=c99 for the cgo code.
# 691   15169         DO NOT SUBMIT: Temporarily disable go:test
# 692   15167                               Fix some Bash issues
# 693   15166      [CMake] Add bazel tests for python file lists
# 694   15163              Fix problem with camera on Android TV
# 695   15162  tf.data.Dataset.from_generator creates too man...
# 696   15160                  Installing Tensorflow from source
# 697   15159           Unable access S3 using the S3 filesystem
# 698   15158  Feature: MonitoredSession should have run() me...
# 699   15157  Feature: GANEstimator allow passing of namedtu...
# 700   15155              Input too short to compute filterbank
# 701   15152                      Strange Dataset API behaviour
# 702   15148               Using function defun and while loops
# 703   15147             summary_image_op_test_fixed_on_ppc64le
# 704   15146  Allow keras applications to load weights from ...
# 705   15141  MKL: Revving mkl-dnn to include all changes be...
# 706   15139  Support --config=monolithic in tf.sysconfig.ge...
# 707   15138     Document tf-coreml converter in lite/README.md
# 708   15137            Tensorflow broken by new Bazel versions
# 709   15135          Solved for MNIST file downloading problem
# 710   15133  Revert "Speed up safe_strtod and safe_strtof f...
# 711   15132                      Add decode_compressed support
# 712   15129  build error: undefined reference to `clock_get...
# 713   15128  GPU memory increases in multiples of batch_siz...
#
#                                                 labels  \
# 0                                             cla: yes
# 1                                                  NaN
# 2                           stat:awaiting tensorflower
# 3                                                  NaN
# 4               awaiting testing (then merge),cla: yes
# 5                                                  NaN
# 6                 stat:awaiting tensorflower,type:docs
# 7                                             cla: yes
# 8                                             cla: yes
# 9                                             cla: yes
# 10                                                 NaN
# 11                                            cla: yes
# 12         stat:awaiting response,type:bug/performance
# 13                                                 NaN
# 14                                                 NaN
# 15                                            cla: yes
# 16                                                 NaN
# 17                                            cla: yes
# 18                              stat:awaiting response
# 19                                                 NaN
# 20                                            cla: yes
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                            cla: yes
# 25                          stat:awaiting tensorflower
# 26                                                 NaN
# 27              awaiting testing (then merge),cla: yes
# 28              awaiting testing (then merge),cla: yes
# 29                          stat:awaiting tensorflower
# ..                                                 ...
# 684  stat:awaiting tensorflower,stat:community support
# 685                               type:bug/performance
# 686                                                NaN
# 687                                           cla: yes
# 688             awaiting testing (then merge),cla: yes
# 689            stat:awaiting tensorflower,type:feature
# 690                                           cla: yes
# 691                                           cla: yes
# 692             awaiting testing (then merge),cla: yes
# 693                           awaiting review,cla: yes
# 694                           awaiting review,cla: yes
# 695                                                NaN
# 696                                                NaN
# 697                             stat:awaiting response
# 698                                                NaN
# 699                                                NaN
# 700                                                NaN
# 701                                                NaN
# 702                               type:bug/performance
# 703                           awaiting review,cla: yes
# 704             awaiting testing (then merge),cla: yes
# 705             awaiting testing (then merge),cla: yes
# 706             awaiting testing (then merge),cla: yes
# 707                                 cla: yes,comp:lite
# 708                         stat:awaiting tensorflower
# 709                           awaiting review,cla: yes
# 710                                           cla: yes
# 711             awaiting testing (then merge),cla: yes
# 712                             stat:community support
# 713                                       type:support
#
#                                                   body  assignees  milestone  \
# 0                              Fixed a couple of typos          0        NaN
# 1    ### System information\r\r\n- **Have I written...          0        NaN
# 2    ### System information\r\r\n- **Have I written...          0        NaN
# 3    ### System information\r\r\n- **Have I written...          0        NaN
# 4                                 Fixing markdown typo          0        NaN
# 5    Please go to Stack Overflow for help and suppo...          0        NaN
# 6    Go tot the page \r\r\nhttps://www.tensorflow.o...          1        NaN
# 7                                                  NaN          0        NaN
# 8    - [x] Fix build error\r\r\n- [x] Update test\r...          0        NaN
# 9                                                  NaN          0        NaN
# 10   I get this error message when trying to build ...          0        NaN
# 11   The link syntax was inverted, that is, round b...          0        NaN
# 12   ### System information\r\r\n- **Have I written...          0        NaN
# 13   How to install TF on banana m64? OS: Linux bpi...          0        NaN
# 14   ### System information\r\r\n- **Have I written...          0        NaN
# 15                              * Fix xcode path error          0        NaN
# 16   I use the batch norm layer like this:\r\r\n`de...          0        NaN
# 17     # C0330 bad-continuation\r\r\n  # C0301 line...          0        NaN
# 18   TF's  high level API  is very convenient to de...          1        NaN
# 19   My understanding is that paramenters of neural...          0        NaN
# 20                                                 NaN          0        NaN
# 21   This is a request for allowing to pass a dict ...          0        NaN
# 22   ### System information\r\r\n- **OS**:Windows 1...          0        NaN
# 23   ### System information\r\r\n- **Have I written...          0        NaN
# 24                                                 NaN          0        NaN
# 25   I am trying to run the DeepLab Resnet (https:/...          0        NaN
# 26   Dear all, \r\r\nI follow  post in "https://blo...          1        NaN
# 27                                                 NaN          0        NaN
# 28                                                 NaN          0        NaN
# 29   Please go to Stack Overflow for help and suppo...          0        NaN
# ..                                                 ...        ...        ...
# 684  ### System information\r\r\n- **Have I written...          0        NaN
# 685  ### System information\r\r\n- **Have I written...          1        NaN
# 686  I am working on windows 10, Python 3.6 and ten...          0        NaN
# 687                                                NaN          1        NaN
# 688  I have built the fix on x86 linux no gpu and i...          1        NaN
# 689  In the documentation for [Passing input_fn Dat...          0        NaN
# 690  This should fix the error:\r\r\ngithub.com/ten...          1        NaN
# 691                                context: b/70154286          1        NaN
# 692  Argument mixes string and array. Use `*` or se...          1        NaN
# 693                          Progressing #10296 \r\r\n          1        NaN
# 694  For a scenario of using a usb external camera,...          1        NaN
# 695  ### System information\r\r\n- **Have I written...          1        NaN
# 696  Please go to Stack Overflow for help and suppo...          0        NaN
# 697  ------------------------\r\r\n\r\r\n### System...          0        NaN
# 698  At the moment the session_run_hooks are passed...          0        NaN
# 699  In the current `GANEstimator` implementation i...          1        NaN
# 700  Hi,\r\r\nI am new to tensorflow and i am tryin...          0        NaN
# 701  ### System information\r\r\n- **Have I written...          1        NaN
# 702  Please go to Stack Overflow for help and suppo...          1        NaN
# 703  Hi @gunan , \r\r\nAs we discussed here https:/...          1        NaN
# 704  This PR allows tensorflow.python.keras.applica...          1        NaN
# 705  This commit will pull the latest changes from ...          1        NaN
# 706  Currently, `tf.sysconfig.get_link_flags()` alw...          1        NaN
# 707                                                NaN          0        NaN
# 708  Simplest way to reproduce the issue, run:\r\r\...          0        NaN
# 709  A lot of folks (#6742, #8126, #8134,#8116) wer...          1        NaN
# 710
# e-conversion library (#12102)"\r\r\n\r\r\nThi...          0        NaN
# 711  This fix tries to address the issue raised in ...          1        NaN
# 712  ### System information\r\r\n- **Have I written...          0        NaN
# 713  ### System information\r\r\n- **Have I written...          0        NaN
#
#      comments            created_at author_association          address_date
# 0           3  2018-02-03T18:42:26Z        CONTRIBUTOR  2018-02-03T18:48:31Z
# 1           1  2018-02-03T01:07:58Z        CONTRIBUTOR  2018-02-03T01:39:35Z
# 2           3  2018-02-02T20:29:29Z               NONE  2018-02-02T23:12:50Z
# 3           1  2018-02-02T15:19:12Z               NONE  2018-02-02T17:38:10Z
# 4           4  2018-02-02T10:10:12Z        CONTRIBUTOR  2018-02-02T10:12:07Z
# 5           1  2018-02-02T09:14:57Z               NONE  2018-02-02T18:52:08Z
# 6           4  2018-02-02T03:58:02Z               NONE  2018-02-02T18:44:40Z
# 7           1  2018-02-02T01:59:52Z             MEMBER  2018-02-02T02:02:15Z
# 8           2  2018-02-01T19:00:57Z             MEMBER  2018-02-02T00:54:42Z
# 9           1  2018-02-01T18:30:59Z             MEMBER  2018-02-01T18:57:50Z
# 10          9  2018-02-01T15:52:21Z               NONE  2018-02-01T16:51:44Z
# 11          4  2018-02-01T15:38:23Z        CONTRIBUTOR  2018-02-01T15:39:39Z
# 12          3  2018-02-01T13:04:29Z               NONE  2018-02-02T03:49:17Z
# 13          1  2018-02-01T12:14:54Z               NONE  2018-02-01T18:01:59Z
# 14         12  2018-02-01T10:38:27Z               NONE  2018-02-01T11:53:15Z
# 15          3  2018-02-01T10:24:43Z        CONTRIBUTOR  2018-02-01T10:31:45Z
# 16          1  2018-02-01T10:02:01Z               NONE  2018-02-02T02:10:41Z
# 17          1  2018-02-01T09:55:53Z             MEMBER  2018-02-01T10:22:31Z
# 18          5  2018-02-01T06:34:16Z               NONE  2018-02-02T02:08:28Z
# 19          1  2018-02-01T05:56:36Z               NONE  2018-02-01T18:02:23Z
# 20          3  2018-02-01T01:56:29Z             MEMBER  2018-02-01T01:57:15Z
# 21          5  2018-01-31T22:24:53Z               NONE  2018-01-31T23:00:57Z
# 22          2  2018-01-31T18:17:24Z               NONE  2018-01-31T19:05:22Z
# 23          1  2018-01-31T16:34:00Z               NONE  2018-01-31T19:24:53Z
# 24          1  2018-01-31T15:22:47Z        CONTRIBUTOR  2018-02-01T01:41:12Z
# 25          2  2018-01-31T11:59:09Z               NONE  2018-01-31T18:19:06Z
# 26          7  2018-01-31T10:23:42Z               NONE  2018-02-02T05:15:49Z
# 27          1  2018-01-31T03:08:35Z        CONTRIBUTOR  2018-01-31T15:25:25Z
# 28          1  2018-01-31T00:18:08Z        CONTRIBUTOR  2018-01-31T00:29:27Z
# 29          4  2018-01-30T22:19:50Z               NONE  2018-01-30T23:11:10Z
# ..        ...                   ...                ...                   ...
# 684         4  2017-12-07T08:44:16Z        CONTRIBUTOR  2017-12-07T18:28:45Z
# 685         5  2017-12-07T08:23:46Z               NONE  2017-12-07T18:45:59Z
# 686         1  2017-12-07T04:04:51Z               NONE  2017-12-07T04:10:34Z
# 687         5  2017-12-07T03:47:41Z        CONTRIBUTOR  2017-12-07T03:54:42Z
# 688        11  2017-12-07T02:17:27Z        CONTRIBUTOR  2017-12-07T02:19:06Z
# 689        10  2017-12-07T01:45:44Z               NONE  2017-12-07T12:30:03Z
# 690         3  2017-12-06T22:30:54Z             MEMBER  2017-12-06T22:31:02Z
# 691         3  2017-12-06T22:03:36Z        CONTRIBUTOR  2017-12-06T22:04:11Z
# 692         2  2017-12-06T20:35:47Z        CONTRIBUTOR  2017-12-07T04:07:29Z
# 693        25  2017-12-06T20:15:04Z        CONTRIBUTOR  2017-12-08T15:16:23Z
# 694         4  2017-12-06T19:03:15Z        CONTRIBUTOR  2017-12-13T19:04:45Z
# 695         2  2017-12-06T18:50:12Z               NONE  2017-12-06T19:09:56Z
# 696         1  2017-12-06T15:54:22Z               NONE  2017-12-06T17:08:40Z
# 697        17  2017-12-06T15:37:22Z               NONE  2017-12-06T18:01:33Z
# 698         8  2017-12-06T14:50:46Z               NONE  2017-12-06T17:05:57Z
# 699         4  2017-12-06T14:44:17Z        CONTRIBUTOR  2017-12-07T01:44:54Z
# 700         1  2017-12-06T13:31:40Z               NONE  2017-12-06T18:05:32Z
# 701         2  2017-12-06T11:38:01Z               NONE  2017-12-06T17:51:57Z
# 702         4  2017-12-06T08:38:54Z               NONE  2017-12-06T17:21:27Z
# 703         6  2017-12-06T08:34:16Z        CONTRIBUTOR  2017-12-07T06:07:34Z
# 704         2  2017-12-06T07:41:19Z        CONTRIBUTOR  2017-12-11T20:28:09Z
# 705         3  2017-12-05T22:30:35Z        CONTRIBUTOR  2017-12-06T14:38:40Z
# 706        13  2017-12-05T20:22:48Z        CONTRIBUTOR  2017-12-05T20:24:57Z
# 707         2  2017-12-05T20:14:29Z        CONTRIBUTOR  2017-12-05T20:15:02Z
# 708         5  2017-12-05T18:46:47Z               NONE  2017-12-05T18:56:14Z
# 709         9  2017-12-05T16:53:17Z               NONE  2017-12-07T15:15:00Z
# 710         3  2017-12-05T15:06:55Z        CONTRIBUTOR  2017-12-05T16:25:58Z
# 711        10  2017-12-05T15:04:15Z             MEMBER  2017-12-19T02:02:23Z
# 712         9  2017-12-05T14:19:20Z               NONE  2017-12-05T18:58:43Z
# 713         3  2017-12-05T14:08:47Z               NONE  2017-12-06T17:16:19Z
#
# [714 rows x 10 columns]
